# %% [markdown]
# # ----------------------------TER Picopatt — Analyse des données -----------------

# %% [markdown]
# ##  1) Importation des librairies et configuration des chemins
#
#  Importation des librairies principales et définition des dossiers de travail.

# %%
from pathlib import Path
import re, unicodedata
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import drive
drive.mount('/content/drive')

# Dossiers de données et de sortie
DATA_DIR = Path("/content/drive/MyDrive/dataproc")
OUTPUT_DIR = Path("./outputs"); OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
FIG_DIR = OUTPUT_DIR / "figures"; FIG_DIR.mkdir(parents=True, exist_ok=True)

# Affichage complet des colonnes
pd.set_option("display.max_columns", 200)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## 2) Fonctions utilitaires
#
# Définition de fonctions pour normaliser les textes, extraire le nom du parcours, parser les dates et attribuer un créneau horaire ('M1'
# 'M4').

# %%
def strip_accents(s):
    # Supprime les accents d'une chaîne
    if pd.isna(s): return s
    return ''.join(c for c in unicodedata.normalize('NFKD', str(s)) if not unicodedata.combining(c))

def normalize_track(x):
    # Nettoie et rassemble les noms de parcours
    if pd.isna(x): return np.nan
    x = strip_accents(str(x)).lower().strip()
    x = x.replace("boulevard", "boulevards")
    if "antigone" in x: return "antigone"
    if "boulevards" in x: return "boulevards"
    if "ecusson" in x: return "ecusson"
    return np.nan

def infer_track_from_filename(name: str):
    # Déduit le parcours à partir du nom du fichier
    n = strip_accents(name.lower())
    if "antigone" in n:   return "antigone"
    if "boulevard" in n:  return "boulevards"
    if "ecusson" in n:    return "ecusson"
    return np.nan

def parse_fr_ts(s):
    # Convertit les dates au format français en datetime
    return pd.to_datetime(s, errors="coerce", dayfirst=True)

def assign_M_slot(ts: pd.Timestamp):
    # Associe chaque timestamp à un créneau horaire (matin, midi, etc.)
    if pd.isna(ts): return np.nan
    h = int(ts.hour)
    if h in (8,9):   return "M1"
    if h in (11,12): return "M2"
    if h in (14,15): return "M3"
    if h in (17,18): return "M4"
    return np.nan

# %% [markdown]
# ## 3) Chargement et préparation des données
#
# Lecture de tous les fichiers de données ('.csv', '.xlsx') dans le dossier 'DATAproc', nettoyage et harmonisation des colonnes, puis ajout des colonnes 'M_slot' (créneau horaire) et 'date'.
#
# Nous préparons et vérifions les données brutes avant toute analyse.
#
# Comme elles viennent de plusieurs fichiers, plusieurs jours, parcours, on va  :
#
# les fusionner proprement dans un seul tableau,
# uniformiser les colonnes (mêmes noms, même format),
# et vérifier la couverture temporelle et la répartition des mesures.

# %%
from pathlib import Path
import pandas as pd
import numpy as np

def read_any(p: Path) -> pd.DataFrame:
    """Lit un fichier (CSV ou Excel), en essayant plusieurs séparateurs."""
    if p.suffix.lower() in (".xlsx", ".xls"):
        df = pd.read_excel(p)
    else:
        df = None
        for sep in [",", ";", "\t"]:
            try:
                temp = pd.read_csv(p, sep=sep)
                if temp.shape[1] >= 5:  # On considère un fichier valide s'il a plusieurs colonnes
                    df = temp
                    break
            except Exception:
                continue
        if df is None:
            raise ValueError(f"Impossible de lire le fichier : {p}")
    df["__source_file"] = p.name
    return df


def load_all(data_dir: Path) -> pd.DataFrame:
    """Charge et fusionne tous les fichiers du dossier en un seul DataFrame."""
    paths = sorted([p for p in data_dir.rglob("*") if p.suffix.lower() in (".csv", ".xlsx", ".xls")])
    assert paths, f"Aucun fichier trouvé dans {data_dir.resolve()}"

    frames = []
    for p in paths:
        df = read_any(p)

        # Conversion du timestamp
        if "timestamp" in df.columns:
            df["timestamp"] = parse_fr_ts(df["timestamp"])

        # Normalisation du nom de parcours à partir du nom du fichier
        trk_file = infer_track_from_filename(p.name)
        if "track_id" not in df.columns:
            df["track_id"] = trk_file
        else:
            df["track_id"] = df["track_id"].map(normalize_track)
            if df["track_id"].notna().any():
                df["track_id"] = df["track_id"].ffill().bfill()
            df["track_id"] = df["track_id"].fillna(trk_file)

        # Fusion des coordonnées GPS RTK et ontrack
        for c in ["lon_rtk", "lat_rtk", "lon_ontrack", "lat_ontrack"]:
            if c not in df.columns:
                df[c] = np.nan
        df["lon"] = df["lon_rtk"].where(df["lon_rtk"].notna(), df["lon_ontrack"])
        df["lat"] = df["lat_rtk"].where(df["lat_rtk"].notna(), df["lat_ontrack"])

        frames.append(df)

    return pd.concat(frames, ignore_index=True, sort=False)


# --- Chargement complet ---
raw = load_all(DATA_DIR)
raw["M_slot"] = raw["timestamp"].map(assign_M_slot)
raw["date"] = raw["timestamp"].dt.date

# --- Résumé rapide ---
print("Couverture :", raw["timestamp"].min(), "->", raw["timestamp"].max())
print("Parcours :", raw["track_id"].dropna().unique())
print(
    raw.pivot_table(index="track_id", columns="M_slot",
                    values="timestamp", aggfunc="count")
       .fillna(0)
       .astype(int)
)
# Out:
# /tmp/ipython-input-2164694065.py:26: UserWarning: Parsing dates in %Y-%m-%d %H:%M:%S format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   return pd.to_datetime(s, errors="coerce", dayfirst=True)
# /tmp/ipython-input-2164694065.py:26: UserWarning: Parsing dates in %Y-%m-%d %H:%M:%S format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   return pd.to_datetime(s, errors="coerce", dayfirst=True)
# /tmp/ipython-input-2164694065.py:26: UserWarning: Parsing dates in %Y-%m-%d %H:%M:%S format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   return pd.to_datetime(s, errors="coerce", dayfirst=True)
# /tmp/ipython-input-2164694065.py:26: UserWarning: Parsing dates in %Y-%m-%d %H:%M:%S format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   return pd.to_datetime(s, errors="coerce", dayfirst=True)
# /tmp/ipython-input-2164694065.py:26: UserWarning: Parsing dates in %Y-%m-%d %H:%M:%S format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   return pd.to_datetime(s, errors="coerce", dayfirst=True)
# /tmp/ipython-input-2164694065.py:26: UserWarning: Parsing dates in %Y-%m-%d %H:%M:%S format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   return pd.to_datetime(s, errors="coerce", dayfirst=True)
# /tmp/ipython-input-2164694065.py:26: UserWarning: Parsing dates in %Y-%m-%d %H:%M:%S format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   return pd.to_datetime(s, errors="coerce", dayfirst=True)
# /tmp/ipython-input-2164694065.py:26: UserWarning: Parsing dates in %Y-%m-%d %H:%M:%S format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   return pd.to_datetime(s, errors="coerce", dayfirst=True)
# /tmp/ipython-input-2164694065.py:26: UserWarning: Parsing dates in %Y-%m-%d %H:%M:%S format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   return pd.to_datetime(s, errors="coerce", dayfirst=True)
# /tmp/ipython-input-2164694065.py:26: UserWarning: Parsing dates in %Y-%m-%d %H:%M:%S format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   return pd.to_datetime(s, errors="coerce", dayfirst=True)
# /tmp/ipython-input-2164694065.py:26: UserWarning: Parsing dates in %Y-%m-%d %H:%M:%S format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   return pd.to_datetime(s, errors="coerce", dayfirst=True)
# /tmp/ipython-input-2164694065.py:26: UserWarning: Parsing dates in %Y-%m-%d %H:%M:%S format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   return pd.to_datetime(s, errors="coerce", dayfirst=True)
# /tmp/ipython-input-2164694065.py:26: UserWarning: Parsing dates in %Y-%m-%d %H:%M:%S format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   return pd.to_datetime(s, errors="coerce", dayfirst=True)
# /tmp/ipython-input-2164694065.py:26: UserWarning: Parsing dates in %Y-%m-%d %H:%M:%S format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   return pd.to_datetime(s, errors="coerce", dayfirst=True)
# /tmp/ipython-input-2164694065.py:26: UserWarning: Parsing dates in %Y-%m-%d %H:%M:%S format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   return pd.to_datetime(s, errors="coerce", dayfirst=True)
# /tmp/ipython-input-2164694065.py:26: UserWarning: Parsing dates in %Y-%m-%d %H:%M:%S format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   return pd.to_datetime(s, errors="coerce", dayfirst=True)
# /tmp/ipython-input-2164694065.py:26: UserWarning: Parsing dates in %Y-%m-%d %H:%M:%S format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   return pd.to_datetime(s, errors="coerce", dayfirst=True)
# /tmp/ipython-input-2164694065.py:26: UserWarning: Parsing dates in %Y-%m-%d %H:%M:%S format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   return pd.to_datetime(s, errors="coerce", dayfirst=True)
# /tmp/ipython-input-2164694065.py:26: UserWarning: Parsing dates in %Y-%m-%d %H:%M:%S format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   return pd.to_datetime(s, errors="coerce", dayfirst=True)
# /tmp/ipython-input-2164694065.py:26: UserWarning: Parsing dates in %Y-%m-%d %H:%M:%S format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   return pd.to_datetime(s, errors="coerce", dayfirst=True)
# /tmp/ipython-input-2164694065.py:26: UserWarning: Parsing dates in %Y-%m-%d %H:%M:%S format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   return pd.to_datetime(s, errors="coerce", dayfirst=True)
# /tmp/ipython-input-2164694065.py:26: UserWarning: Parsing dates in %Y-%m-%d %H:%M:%S format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   return pd.to_datetime(s, errors="coerce", dayfirst=True)
# /tmp/ipython-input-2164694065.py:26: UserWarning: Parsing dates in %Y-%m-%d %H:%M:%S format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   return pd.to_datetime(s, errors="coerce", dayfirst=True)
# /tmp/ipython-input-2164694065.py:26: UserWarning: Parsing dates in %Y-%m-%d %H:%M:%S format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   return pd.to_datetime(s, errors="coerce", dayfirst=True)
# /tmp/ipython-input-2164694065.py:26: UserWarning: Parsing dates in %Y-%m-%d %H:%M:%S format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   return pd.to_datetime(s, errors="coerce", dayfirst=True)
# /tmp/ipython-input-2164694065.py:26: UserWarning: Parsing dates in %Y-%m-%d %H:%M:%S format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   return pd.to_datetime(s, errors="coerce", dayfirst=True)
# /tmp/ipython-input-2164694065.py:26: UserWarning: Parsing dates in %Y-%m-%d %H:%M:%S format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   return pd.to_datetime(s, errors="coerce", dayfirst=True)
# /tmp/ipython-input-2164694065.py:26: UserWarning: Parsing dates in %Y-%m-%d %H:%M:%S format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   return pd.to_datetime(s, errors="coerce", dayfirst=True)
# /tmp/ipython-input-2164694065.py:26: UserWarning: Parsing dates in %Y-%m-%d %H:%M:%S format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   return pd.to_datetime(s, errors="coerce", dayfirst=True)
# /tmp/ipython-input-2164694065.py:26: UserWarning: Parsing dates in %Y-%m-%d %H:%M:%S format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   return pd.to_datetime(s, errors="coerce", dayfirst=True)
# /tmp/ipython-input-2164694065.py:26: UserWarning: Parsing dates in %Y-%m-%d %H:%M:%S format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   return pd.to_datetime(s, errors="coerce", dayfirst=True)
# /tmp/ipython-input-2164694065.py:26: UserWarning: Parsing dates in %Y-%m-%d %H:%M:%S format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   return pd.to_datetime(s, errors="coerce", dayfirst=True)
# /tmp/ipython-input-2164694065.py:26: UserWarning: Parsing dates in %Y-%m-%d %H:%M:%S format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   return pd.to_datetime(s, errors="coerce", dayfirst=True)
# /tmp/ipython-input-2164694065.py:26: UserWarning: Parsing dates in %Y-%m-%d %H:%M:%S format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   return pd.to_datetime(s, errors="coerce", dayfirst=True)
# /tmp/ipython-input-2164694065.py:26: UserWarning: Parsing dates in %Y-%m-%d %H:%M:%S format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   return pd.to_datetime(s, errors="coerce", dayfirst=True)
# /tmp/ipython-input-2164694065.py:26: UserWarning: Parsing dates in %Y-%m-%d %H:%M:%S format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   return pd.to_datetime(s, errors="coerce", dayfirst=True)
# /tmp/ipython-input-2164694065.py:26: UserWarning: Parsing dates in %Y-%m-%d %H:%M:%S format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   return pd.to_datetime(s, errors="coerce", dayfirst=True)
# /tmp/ipython-input-2164694065.py:26: UserWarning: Parsing dates in %Y-%m-%d %H:%M:%S format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   return pd.to_datetime(s, errors="coerce", dayfirst=True)
# /tmp/ipython-input-2164694065.py:26: UserWarning: Parsing dates in %Y-%m-%d %H:%M:%S format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   return pd.to_datetime(s, errors="coerce", dayfirst=True)
# /tmp/ipython-input-2164694065.py:26: UserWarning: Parsing dates in %Y-%m-%d %H:%M:%S format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   return pd.to_datetime(s, errors="coerce", dayfirst=True)
# Couverture : 2024-03-12 08:30:07 -> 2025-09-01 19:08:20
# Parcours : ['antigone' 'boulevards' 'ecusson']
# M_slot         M1     M2     M3     M4
# track_id
# antigone    27523  27190  29139  28923
# boulevards  21279  28399  18017  24694
# ecusson     19761  20945  17813  15822

# %% [markdown]
# ## Résultat:
#
# Les données couvrent un intervalle de temps.
# On distingue trois zones de collecte principales du chariot : antigone, boulevards et ecusson.
#
# On observe également quatre passages par jour (matin, midi, après-midi et soir), réalisés à différents moments de la journée.
#
# Globalement, la base de données est bonne et bien équilibrée entre les parcours et les passages.
# Cependant, on remarque que le parcours Écusson contient un peu moins de données, ce qui peut indiquer que certains passages n’ont pas été effectués, qu’un problème de mesure est survenu ou tout simplement moins de mesures ont été éffectues pour ecusson.

# %% [markdown]
# ## 4) Analyse exploratoire rapide
#
# ### 4.1) Comptage global par parcours
#
#
#
# Affiche la période couverte par les données, la liste des parcours disponibles, le taux de valeurs manquantes globales et des variables météo, et le nombre d’enregistrements par parcours et par créneau horaire ('M_slot').

# %%
# Période temporelle couverte
print("Couverture temporelle :", raw["timestamp"].min(), "->", raw["timestamp"].max())

# Liste des parcours présents dans les données
print("Parcours disponibles :", raw["track_id"].dropna().unique())

# Taux de valeurs manquantes (20 colonnes les plus concernées)
missing = raw.isna().mean().sort_values(ascending=False)
print("Taux de valeurs manquantes (top 20) :")
display(missing.head(20))

# Comptage global par parcours
print("Comptage par parcours :")
display(raw["track_id"].value_counts())

# Calcul du pourcentage de valeurs manquantes sur les variables météo
na = raw[METEO].isna().mean().sort_values(ascending=False) * 100

# Visualisation graphique
plt.figure(figsize=(10, 4))
plt.bar(na.index, na.values)
plt.title("Taux de valeurs manquantes (%)")
plt.xticks(rotation=90)
plt.ylabel("%")
plt.tight_layout()
plt.savefig(FIG_DIR / "na_pct_vars.png", dpi=150)
plt.show()
# Out:
# Couverture temporelle : 2024-03-12 08:30:07 -> 2025-09-01 19:08:20
# Parcours disponibles : ['antigone' 'boulevards' 'ecusson']
# Taux de valeurs manquantes (top 20) :
# project_id          0.999786
# section_warning     0.999660
# section_speed       0.988983
# section_weather     0.988983
# section_duration    0.988983
# M_slot              0.181012
# gnss_accuracy       0.000006
# lat_rtk             0.000006
# lon_rtk             0.000006
# section_id          0.000000
# track_id            0.000000
# timestamp           0.000000
# segment_id          0.000000
# point_id            0.000000
# lat_ontrack         0.000000
# sun_azimuth         0.000000
# sun_height          0.000000
# tair_thermohygro    0.000000
# lon_ontrack         0.000000
# tair_tc2            0.000000
# dtype: float64
# Comptage par parcours :
# track_id
# antigone      121457
# boulevards    115962
# ecusson       103862
# Name: count, dtype: int64
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3819675712.py in <cell line: 0>()
#      15
#      16 # Calcul du pourcentage de valeurs manquantes sur les variables météo
# ---> 17 na = raw[METEO].isna().mean().sort_values(ascending=False) * 100
#      18
#      19 # Visualisation graphique
#
# NameError: name 'METEO' is not defined

# %% [markdown]
# ## Résultat:
#
# Les variables de mesures principales présentent très peu de valeurs manquantes, ce qui garantit une base de données fiable et exploitable.
#
# Certaines colonnes pour les sections sont quasiment vides, ce qui est normal compte tenu de la configuration du jeu de données, et elles pourront donc être ignorées lors des analyses.
#
# On observe également le nombre total de relevés par parcours, avec Écusson qui présente le volume le plus faible.

# %% [markdown]
# ### 4.2) Comptage croisé : parcours x créneau horaire
#
#  Carte de chaleur des échantillons par parcours et créneau horaire
#
# Ce bloc affiche une **heatmap** montrant le **nombre d’échantillons collectés** pour chaque combinaison `parcours × M_slot` (M1 à M4).
# Cela permet d’identifier les périodes ou parcours avec plus ou moins de données.

# %%
# ## Répartition des mesures par parcours et créneau horaire (M-slot)

# Comptage croisé : parcours × créneau horaire
raw["passage_slot"] = raw["M_slot"]

# Tableau récapitulatif du nombre de mesures
tab = (
    raw.dropna(subset=["track_id", "M_slot"])
       .pivot_table(
           index="track_id",
           columns="M_slot",
           values="timestamp",
           aggfunc="count",
           observed=True
       )
       .reindex(columns=["M1", "M2", "M3", "M4"])
       .fillna(0)
       .astype(int)
)

# Affichage du tableau
print("Nombre d’échantillons par parcours et par créneau horaire :")
display(tab)

# --- Visualisation : Heatmap ---
plt.figure(figsize=(6, 4))
plt.imshow(tab.values, aspect="auto")
plt.xticks(range(tab.shape[1]), tab.columns)
plt.yticks(range(tab.shape[0]), tab.index)
plt.title("Nombre d’échantillons — parcours × M-slot")
plt.colorbar(label="N")
plt.tight_layout()

# Sauvegarde et affichage
plt.savefig(FIG_DIR / "heatmap_counts_parcours_M.png", dpi=150)
plt.show()
# Out:
# Nombre d’échantillons par parcours et par créneau horaire :
# M_slot         M1     M2     M3     M4
# track_id
# antigone    27523  27190  29139  28923
# boulevards  21279  28399  18017  24694
# ecusson     19761  20945  17813  15822

# %% [markdown]
# # Résultat:
#
#
# 	•	Le parcours Antigone possède le plus grand nombre de mesures sur l’ensemble des créneaux.
# 	•	Le parcours Boulevards présente davantage de données sur le créneau M2 (midi), mais moins sur M3 (après-midi).
# 	•	Le parcours Écusson contient globalement moins de mesures sur tous les créneaux.
# 	•	Le jeu de données couvre bien les quatre créneaux horaires de la journée (M1, M2, M3, M4) pour chaque parcours.
#
# #  5) Pourquoi Écusson a moins de données ?

# %%
# Période de mesure et nombre de jours distincts
periode_parcours = (
    raw.dropna(subset=["track_id", "timestamp"])
       .groupby("track_id")
       .agg(
           date_debut=("timestamp", "min"),
           date_fin=("timestamp", "max"),
           nb_jours=("date", "nunique")
       )
       .reset_index()
)

# Nombre total de passages (jour + M_slot) par parcours
nb_passages_par_parcours = (
    raw.dropna(subset=["track_id", "M_slot", "date"])
       .groupby("track_id")[["date", "M_slot"]]
       .apply(lambda x: x.drop_duplicates(subset=["date", "M_slot"]).shape[0])
       .reset_index(name="nb_passages")
)

# Détail des passages par créneau horaire (M1, M2, M3, M4)
nb_passages_par_Mslot = (
    raw.dropna(subset=["track_id", "M_slot", "date"])
       .groupby(["track_id", "M_slot"])
       .apply(lambda x: x.drop_duplicates(subset=["date", "M_slot"]).shape[0])
       .reset_index(name="nb_passages")
       .pivot(index="track_id", columns="M_slot", values="nb_passages")
       .fillna(0)
       .astype(int)
)

# Fusion des résultats en un tableau unique
synthese_passages = (
    periode_parcours
    .merge(nb_passages_par_parcours, on="track_id", how="left")
    .merge(nb_passages_par_Mslot, on="track_id", how="left")
)

display(synthese_passages)

## Nombre de passages par parcours et créneau horaire

plt.figure(figsize=(8, 5))
nb_passages_par_Mslot.plot(
    kind="bar",
    figsize=(8, 5),
    rot=0,
    title="Nombre de passages distincts par parcours et créneau horaire"
)
plt.xlabel("Parcours")
plt.ylabel("Nombre de passages (jour + créneau horaire)")
plt.tight_layout()

# Sauvegarde et affichage
plt.savefig(FIG_DIR / "nb_passages_distincts_par_Mslot.png", dpi=150)
plt.show()
# Out:
# /tmp/ipython-input-757512696.py:25: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda x: x.drop_duplicates(subset=["date", "M_slot"]).shape[0])
#      track_id          date_debut            date_fin  nb_jours  nb_passages  \
# 0    antigone 2024-06-12 14:44:05 2025-09-01 19:08:20         8           29
# 1  boulevards 2024-05-12 08:30:27 2025-07-01 19:10:08         7           23
# 2     ecusson 2024-03-12 08:30:07 2025-01-14 19:18:28         7           21
#
#    M1  M2  M3  M4
# 0   7   7   8   7
# 1   5   7   5   6
# 2   6   6   5   4

# %%
from pathlib import Path
import pandas as pd

# Dossier contenant les fichiers
DATA_DIR = Path("/content/drive/MyDrive/dataproc")

# récupère uniquement les fichiers liés à "ecusson"
paths_ecusson = sorted([p for p in DATA_DIR.rglob("*ecusson*") if p.suffix.lower() in (".csv", ".xlsx", ".xls")])

#  lire un fichier et extraire les dates présentes
def get_dates_from_file(p):
    try:
        if p.suffix.lower() in (".xlsx", ".xls"):
            df = pd.read_excel(p)
        else:
            df = pd.read_csv(p, sep=None, engine="python")  # détection auto du séparateur
        if "timestamp" in df.columns:
            df["timestamp"] = pd.to_datetime(df["timestamp"], errors="coerce", dayfirst=True)
            return sorted(df["timestamp"].dropna().dt.date.unique())
        else:
            return []
    except Exception as e:
        print(f" Erreur lecture {p.name}: {e}")
        return []

#  tableau récapitulatif
file_dates = pd.DataFrame([
    {"fichier": p.name, "dates_trouvées": get_dates_from_file(p)}
    for p in paths_ecusson
])

# Affichage du résultat
display(file_dates)

#  combien de jours distincts au total :
all_dates = sorted({d for sublist in file_dates["dates_trouvées"] for d in sublist})
print(f"\n Nombre total de jours uniques mesurés pour ECUSSON : {len(all_dates)}")
# Out:
# /tmp/ipython-input-3228870467.py:18: UserWarning: Parsing dates in %Y-%m-%d %H:%M:%S format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   df["timestamp"] = pd.to_datetime(df["timestamp"], errors="coerce", dayfirst=True)
# /tmp/ipython-input-3228870467.py:18: UserWarning: Parsing dates in %Y-%m-%d %H:%M:%S format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   df["timestamp"] = pd.to_datetime(df["timestamp"], errors="coerce", dayfirst=True)
# /tmp/ipython-input-3228870467.py:18: UserWarning: Parsing dates in %Y-%m-%d %H:%M:%S format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   df["timestamp"] = pd.to_datetime(df["timestamp"], errors="coerce", dayfirst=True)
# /tmp/ipython-input-3228870467.py:18: UserWarning: Parsing dates in %Y-%m-%d %H:%M:%S format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   df["timestamp"] = pd.to_datetime(df["timestamp"], errors="coerce", dayfirst=True)
# /tmp/ipython-input-3228870467.py:18: UserWarning: Parsing dates in %Y-%m-%d %H:%M:%S format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   df["timestamp"] = pd.to_datetime(df["timestamp"], errors="coerce", dayfirst=True)
# /tmp/ipython-input-3228870467.py:18: UserWarning: Parsing dates in %Y-%m-%d %H:%M:%S format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   df["timestamp"] = pd.to_datetime(df["timestamp"], errors="coerce", dayfirst=True)
# /tmp/ipython-input-3228870467.py:18: UserWarning: Parsing dates in %Y-%m-%d %H:%M:%S format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   df["timestamp"] = pd.to_datetime(df["timestamp"], errors="coerce", dayfirst=True)
# /tmp/ipython-input-3228870467.py:18: UserWarning: Parsing dates in %Y-%m-%d %H:%M:%S format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   df["timestamp"] = pd.to_datetime(df["timestamp"], errors="coerce", dayfirst=True)
# /tmp/ipython-input-3228870467.py:18: UserWarning: Parsing dates in %Y-%m-%d %H:%M:%S format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   df["timestamp"] = pd.to_datetime(df["timestamp"], errors="coerce", dayfirst=True)
#                                            fichier dates_trouvées
# 0   picopatt_montpellier_ecusson_20241031_0827.csv   [2024-10-31]
# 1   picopatt_montpellier_ecusson_20241031_1127.csv   [2024-10-31]
# 2   picopatt_montpellier_ecusson_20241031_1425.csv   [2024-10-31]
# 3   picopatt_montpellier_ecusson_20241112_0830.csv   [2024-12-11]
# 4   picopatt_montpellier_ecusson_20241112_1124.csv   [2024-12-11]
# 5   picopatt_montpellier_ecusson_20241112_1430.csv   [2024-12-11]
# 6   picopatt_montpellier_ecusson_20241112_1723.csv   [2024-12-11]
# 7   picopatt_montpellier_ecusson_20241121_0832.csv   [2024-11-21]
# 8   picopatt_montpellier_ecusson_20241121_1729.csv   [2024-11-21]
# 9   picopatt_montpellier_ecusson_20241203_0829.csv   [2024-03-12]
# 10  picopatt_montpellier_ecusson_20241203_1128.csv   [2024-03-12]
# 11  picopatt_montpellier_ecusson_20241203_1423.csv   [2024-03-12]
# 12  picopatt_montpellier_ecusson_20241203_1743.csv   [2024-03-12]
# 13  picopatt_montpellier_ecusson_20241206_1005.csv   [2024-06-12]
# 14  picopatt_montpellier_ecusson_20241212_0829.csv   [2024-12-12]
# 15  picopatt_montpellier_ecusson_20241212_1125.csv   [2024-12-12]
# 16  picopatt_montpellier_ecusson_20241212_1425.csv   [2024-12-12]
# 17  picopatt_montpellier_ecusson_20250114_0832.csv   [2025-01-14]
# 18  picopatt_montpellier_ecusson_20250114_1130.csv   [2025-01-14]
# 19  picopatt_montpellier_ecusson_20250114_1427.csv   [2025-01-14]
# 20  picopatt_montpellier_ecusson_20250114_1726.csv   [2025-01-14]
#  Nombre total de jours uniques mesurés pour ECUSSON : 7

# %% [markdown]
# ## Resultat
#
# Ces résultats montrent que les mesures ont été réalisées sur une période, mais seulement sur quelques journées d’acquisition par parcours.
# Le parcours Antigone a bénéficié de la couverture la plus complète, tandis que Écusson présente le moins de passages.
#
# Elle contient un jour en moins que antigone comme boulevards mais plsu explicite sur les passages ou elle detinet le moins de passages sur le parcours.
#
# Cela montre pourquoi ecusson regroupe moins de valeur

# %% [markdown]
# # 5.1) Vérification des sections mesurées pour le parcours Écusson

# %%
# On isole le parcours "antigone"
df_ecusson = raw[raw["track_id"] == "ecusson"]

# Liste des sections présentes dans le fichier
sections_lues = sorted(df_ecusson["section_id"].dropna().unique())

# On suppose que le parcours doit avoir 75 sections
sections_theoriques = list(range(1, 76))

# On cherche les manquantes
sections_manquantes = sorted(set(sections_theoriques) - set(sections_lues))

print("Nombre total attendu :", len(sections_theoriques))
print("Nombre réellement lus :", len(sections_lues))
print("Sections manquantes :", sections_manquantes)
# Out:
# Nombre total attendu : 75
# Nombre réellement lus : 73
# Sections manquantes : [12, 32]

# %% [markdown]
# ##  Résultat
# Nous savons que le nombre de sections pour un oarcours écusson est de 73 ( vu dans les fichiers ).
# On regarde les sections toujours manquantes dans tout les fichiers écusson ( si certains fichier n 'ont pas certaines sections du a des travaux sur une certaine periode, mais d autre fichiers ont cette donneé, on la conserve).

# %% [markdown]
# ## Statistiques descriptives sur les variables météo
#
# Calcul des statistiques globales, par parcours et par créneau horaire ('M_slot') sur les variables météorologiques présentes dans les données.

# %%
# Liste des variables météo présentes
CANDIDATES = [
    "tair_thermohygro","tair_tc1","tair_tc2","tair_anemo",
    "rh_thermohygro","ws","wdir",
    "sw_up","sw_down","sw_front","sw_back","sw_left","sw_right",
    "lw_up","lw_down","lw_front","lw_back","lw_left","lw_right",
    "tmrt","pet"
]
METEO = [c for c in CANDIDATES if c in raw.columns]
num_cols = [c for c in METEO if c != "wdir"]  # variables numériques classiques


# Fonctions utilitaires

def summary_stats(df, cols):
    # Calcule les statistiques descriptives principales
    q = df[cols].quantile([.10, .25, .50, .75, .90], numeric_only=True).T
    return pd.DataFrame({
        "count": df[cols].count(),
        "na_pct": df[cols].isna().mean() * 100,
        "mean": df[cols].mean(numeric_only=True),
        "std": df[cols].std(numeric_only=True),
        "min": df[cols].min(numeric_only=True),
        "p10": q[.10], "p25": q[.25], "median": q[.50],
        "p75": q[.75], "p90": q[.90],
        "max": df[cols].max(numeric_only=True),
    })

def circular_mean_deg(s):
    # Moyenne circulaire pour les angles (direction du vent)
    r = np.deg2rad(s.dropna().astype(float) % 360.0)
    if r.size == 0: return np.nan
    ang = np.arctan2(np.sin(r).mean(), np.cos(r).mean())
    return np.rad2deg(ang) % 360.0


# Statistiques globales
stats_global = summary_stats(raw, num_cols)
if "wdir" in METEO:
    stats_global.loc["wdir", "mean"] = circular_mean_deg(raw["wdir"])

stats_global.to_csv("outputs/stats_global.xlsx")
display(stats_global)
# Out:
#                      count  na_pct        mean         std         min  \
# tair_thermohygro  341281.0     0.0   12.322580    4.446766   -0.971618
# tair_tc1          341281.0     0.0   20.773164  130.146941    0.007812
# tair_tc2          341281.0     0.0   13.612225   53.550689    0.000000
# tair_anemo        341281.0     0.0   14.543863    4.822161    1.000000
# rh_thermohygro    341281.0     0.0   60.532089   12.035269   37.474861
# ws                341281.0     0.0    1.047698    0.877630    0.000000
# sw_up             341281.0     0.0   49.782584   85.554051    0.000000
# sw_down           341281.0     0.0    7.090579   22.537950    0.000000
# sw_front          341281.0     0.0   54.993113  104.226845    3.323424
# sw_back           341281.0     0.0   37.628652   84.803999    0.000000
# sw_left           341281.0     0.0   26.666477   76.305578    0.000000
# sw_right          341281.0     0.0   57.173672   94.781878    0.000000
# lw_up             341281.0     0.0  363.435073   27.405188  266.539351
# lw_down           341281.0     0.0  392.040498   21.237942  330.894294
# lw_front          341281.0     0.0  388.481091   21.107004  317.796248
# lw_back           341281.0     0.0  386.614032   21.218601  309.552120
# lw_left           341281.0     0.0  392.899925   21.681679  315.678162
# lw_right          341281.0     0.0  388.480124   21.290265  313.077331
# tmrt              341281.0     0.0   19.497133    8.799047    2.424655
# pet               341281.0     0.0   11.353547    6.008448   -5.037205
# wdir                   NaN     NaN  358.071813         NaN         NaN
#
#                          p10         p25      median         p75         p90  \
# tair_thermohygro    6.489281    9.496071   12.129015   15.034333   17.880903
# tair_tc1            6.398438    9.359375   12.000000   15.023438   18.007812
# tair_tc2            6.398438    9.382812   11.953125   14.867188   17.914062
# tair_anemo          8.000000   11.000000   15.000000   17.000000   20.000000
# rh_thermohygro     45.279850   51.145037   58.829862   69.543603   78.094377
# ws                  0.154333    0.463000    0.874555    1.388999    2.109220
# sw_up               0.000000    0.000000   19.431816   54.280126  123.396639
# sw_down             0.000000    0.000000    0.000000    0.000000   18.696829
# sw_front           14.277620   15.882575   26.655764   47.904116   89.354224
# sw_back             4.113576    5.483859   15.175765   33.960958   68.835741
# sw_left             0.000000    0.000000    0.322861   22.408134   61.853058
# sw_right           20.534338   21.522706   30.016879   49.817298   92.842337
# lw_up             326.625260  346.569614  365.492545  381.343028  396.241645
# lw_down           367.766874  378.494614  389.877291  401.843456  423.239340
# lw_front          362.602961  374.269418  387.172788  399.497117  418.987333
# lw_back           360.614658  372.675685  385.021078  397.684957  416.675559
# lw_left           366.339746  378.315567  391.906031  404.404981  423.392149
# lw_right          362.442659  373.935424  387.902403  400.019540  417.740240
# tmrt               12.040703   14.453339   17.208549   21.586146   27.927997
# pet                 4.861958    7.564301   10.410688   14.307505   19.030599
# wdir                     NaN         NaN         NaN         NaN         NaN
#
#                           max
# tair_thermohygro    25.053407
# tair_tc1          2047.992188
# tair_tc2          2047.992188
# tair_anemo          30.000000
# rh_thermohygro      87.657969
# ws                  11.009102
# sw_up              712.930225
# sw_down            341.675115
# sw_front           984.895425
# sw_back            866.605546
# sw_left            915.390118
# sw_right           957.943577
# lw_up              457.708289
# lw_down            512.178666
# lw_front           532.448403
# lw_back            479.900517
# lw_left            520.479126
# lw_right           526.091224
# tmrt                73.053752
# pet                 55.898584
# wdir                      NaN

# %%
# Statistiques par parcours
by_track = []
for t, g in raw.groupby("track_id", dropna=True):
    s = summary_stats(g, num_cols)
    if "wdir" in METEO:
        s.loc["wdir", "mean"] = circular_mean_deg(g["wdir"])
    s.insert(0, "track_id", t)
    by_track.append(s.reset_index(names="variable"))

stats_by_track = pd.concat(by_track, ignore_index=True)
stats_by_track.to_csv("outputs/stats_par_parcours.xlsx", index=False)
display(stats_by_track.head())
# Out:
#            variable  track_id     count  na_pct       mean        std  \
# 0  tair_thermohygro  antigone  121457.0     0.0  14.245584   4.113195
# 1          tair_tc1  antigone  121457.0     0.0  14.160871   4.162505
# 2          tair_tc2  antigone  121457.0     0.0  14.132794   4.132840
# 3        tair_anemo  antigone  121457.0     0.0  16.576262   4.666686
# 4    rh_thermohygro  antigone  121457.0     0.0  68.086875  11.272769
#
#          min        p10        p25     median        p75        p90        max
# 0   5.629435   9.148928  10.510796  14.585718  17.122530  19.531167  24.433890
# 1   5.390625   8.957813  10.570312  14.429688  17.078125  19.304688  25.828125
# 2   5.367188   9.015625  10.570312  14.359375  17.078125  19.304688  25.242188
# 3   7.000000  11.000000  12.000000  16.000000  20.000000  23.000000  29.000000
# 4  41.478447  52.453498  59.320058  67.802167  77.813993  83.217594  87.657969

# %%
# Statistiques par parcours et créneau horaire
def agg_means(g):
    res = {f"{c}_mean": g[c].mean() for c in num_cols}
    if "wdir" in METEO:
        res["wdir_mean_circ"] = circular_mean_deg(g["wdir"])
    return pd.Series(res)

stats_track_M = raw.groupby(["track_id", "M_slot"]).apply(agg_means).reset_index()
stats_track_M.to_excel(OUTPUT_DIR / "stats_parcours_par_Mslot.xlsx", index=False)
display(stats_track_M)
# Out:
# /tmp/ipython-input-2491522816.py:8: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   stats_track_M = raw.groupby(["track_id", "M_slot"]).apply(agg_means).reset_index()
#       track_id M_slot  tair_thermohygro_mean  tair_tc1_mean  tair_tc2_mean  \
# 0     antigone     M1              11.206787      11.117618      11.131297
# 1     antigone     M2              15.129053      15.161173      15.071895
# 2     antigone     M3              16.279904      16.194290      16.129487
# 3     antigone     M4              14.053747      13.872983      13.893078
# 4   boulevards     M1               7.660576       7.333193       7.387541
# 5   boulevards     M2              12.468959      12.430946      12.345501
# 6   boulevards     M3              13.794220      13.642063      13.572954
# 7   boulevards     M4              10.998848      10.721545      10.765054
# 8      ecusson     M1               8.942756     157.011741      33.758839
# 9      ecusson     M2              12.303107      12.253836      12.098766
# 10     ecusson     M3              12.728330      12.552635      12.519115
# 11     ecusson     M4               9.985556       9.795978       9.867012
#
#     tair_anemo_mean  rh_thermohygro_mean   ws_mean  sw_up_mean  sw_down_mean  \
# 0         13.058678            78.422463  0.863910   48.717718      5.793217
# 1         18.481574            66.763626  1.057348  159.649272     29.662831
# 2         18.773259            60.591832  1.335369   78.525242     12.325536
# 3         15.743353            66.975029  1.213080    0.000000      0.000000
# 4          9.680154            66.522219  0.928148   26.369243      2.584970
# 5         15.458361            54.042821  1.395283  114.493248     21.408082
# 6         16.339291            46.796228  0.964854   60.004809      7.053701
# 7         12.755973            61.912273  0.773633    0.000000      0.000000
# 8         10.636152            61.346927  0.801339   13.970999      0.534858
# 9         14.524660            49.982398  1.080622   58.133573      4.487317
# 10        15.191265            47.102115  0.970403   38.552957      2.492398
# 11        11.687018            62.375603  0.935620    0.000923      0.000000
#
#     sw_front_mean  sw_back_mean  sw_left_mean  sw_right_mean  lw_up_mean  \
# 0       58.219302     37.896765     34.566215      65.509012  362.681335
# 1      127.627909     91.995504     89.134463     135.408363  371.469616
# 2       86.710713     55.956563     49.966215      94.537516  367.484429
# 3       14.096395      3.490550      0.000000      20.221727  361.450661
# 4       45.997436     22.644936     10.441044      48.432405  346.833615
# 5      115.024761     95.034469     58.092279      98.982542  348.870487
# 6       85.115316     47.528284     29.433111      62.543484  357.706960
# 7       14.390278      4.282521      0.000000      20.652887  353.315464
# 8       25.328798     14.380907      3.153325      31.271939  362.012677
# 9       48.094146     38.068097     19.104413      57.594965  373.189963
# 10      36.355007     35.804812     15.479199      48.892422  371.742765
# 11      14.111957      3.541104      0.000000      20.423225  369.428606
#
#     lw_down_mean  lw_front_mean  lw_back_mean  lw_left_mean  lw_right_mean  \
# 0     388.799583     385.358779    384.648711    389.414901     383.616588
# 1     407.440311     401.253437    400.909044    405.522931     399.788278
# 2     409.730696     401.963662    401.287310    406.065283     400.585606
# 3     398.289151     391.976673    390.147111    396.268693     390.502187
# 4     371.135947     368.229251    365.902906    372.183546     369.128134
# 5     388.144278     382.573733    382.564721    388.859559     384.580111
# 6     393.827844     388.986783    387.951103    394.555668     390.706583
# 7     383.866415     379.614265    377.138851    384.549191     381.010994
# 8     382.923344     381.479127    377.050138    385.884123     380.896384
# 9     393.200840     392.992274    389.896023    397.766758     392.737310
# 10    395.789306     394.488404    391.015087    399.562428     394.076634
# 11    383.417417     383.809175    380.283388    388.030346     383.350917
#
#     tmrt_mean   pet_mean  wdir_mean_circ
# 0   19.529653  10.842659      358.725688
# 1   29.278455  16.860707        2.255707
# 2   24.892820  15.591107      358.371773
# 3   16.004968  11.282775      357.249837
# 4   14.515659   6.703842        6.154562
# 5   24.188712  12.433204        4.504606
# 6   21.239010  13.057286        2.949620
# 7   13.951566   8.859926      359.416980
# 8   15.177990   7.869711      356.155171
# 9   20.015502  11.427057      356.157187
# 10  19.369810  11.639299      357.070572
# 11  14.613575   8.170099      355.072905

# %% [markdown]
# ##  Statistiques descriptives globales et par parcours
#
# Ce bloc calcule les statistiques principales (moyenne, écart-type, quartiles, etc.)  sur les variables météo disponibles : d’abord globalement, puis séparément pour chaque parcours ('track_id').

# %%
# Global (numériques hors wdir)
num_cols = [c for c in METEO if c != "wdir"]
stats_global = summary_stats(raw, num_cols)
if "wdir" in METEO:
    stats_global.loc["wdir","mean"] = circular_mean_deg(raw["wdir"])
display(stats_global)
stats_global.to_excel(OUTPUT_DIR / "stats_global.xlsx")
# Out:
#                      count  na_pct        mean         std         min  \
# tair_thermohygro  341281.0     0.0   12.322580    4.446766   -0.971618
# tair_tc1          341281.0     0.0   20.773164  130.146941    0.007812
# tair_tc2          341281.0     0.0   13.612225   53.550689    0.000000
# tair_anemo        341281.0     0.0   14.543863    4.822161    1.000000
# rh_thermohygro    341281.0     0.0   60.532089   12.035269   37.474861
# ws                341281.0     0.0    1.047698    0.877630    0.000000
# sw_up             341281.0     0.0   49.782584   85.554051    0.000000
# sw_down           341281.0     0.0    7.090579   22.537950    0.000000
# sw_front          341281.0     0.0   54.993113  104.226845    3.323424
# sw_back           341281.0     0.0   37.628652   84.803999    0.000000
# sw_left           341281.0     0.0   26.666477   76.305578    0.000000
# sw_right          341281.0     0.0   57.173672   94.781878    0.000000
# lw_up             341281.0     0.0  363.435073   27.405188  266.539351
# lw_down           341281.0     0.0  392.040498   21.237942  330.894294
# lw_front          341281.0     0.0  388.481091   21.107004  317.796248
# lw_back           341281.0     0.0  386.614032   21.218601  309.552120
# lw_left           341281.0     0.0  392.899925   21.681679  315.678162
# lw_right          341281.0     0.0  388.480124   21.290265  313.077331
# tmrt              341281.0     0.0   19.497133    8.799047    2.424655
# pet               341281.0     0.0   11.353547    6.008448   -5.037205
# wdir                   NaN     NaN  358.071813         NaN         NaN
#
#                          p10         p25      median         p75         p90  \
# tair_thermohygro    6.489281    9.496071   12.129015   15.034333   17.880903
# tair_tc1            6.398438    9.359375   12.000000   15.023438   18.007812
# tair_tc2            6.398438    9.382812   11.953125   14.867188   17.914062
# tair_anemo          8.000000   11.000000   15.000000   17.000000   20.000000
# rh_thermohygro     45.279850   51.145037   58.829862   69.543603   78.094377
# ws                  0.154333    0.463000    0.874555    1.388999    2.109220
# sw_up               0.000000    0.000000   19.431816   54.280126  123.396639
# sw_down             0.000000    0.000000    0.000000    0.000000   18.696829
# sw_front           14.277620   15.882575   26.655764   47.904116   89.354224
# sw_back             4.113576    5.483859   15.175765   33.960958   68.835741
# sw_left             0.000000    0.000000    0.322861   22.408134   61.853058
# sw_right           20.534338   21.522706   30.016879   49.817298   92.842337
# lw_up             326.625260  346.569614  365.492545  381.343028  396.241645
# lw_down           367.766874  378.494614  389.877291  401.843456  423.239340
# lw_front          362.602961  374.269418  387.172788  399.497117  418.987333
# lw_back           360.614658  372.675685  385.021078  397.684957  416.675559
# lw_left           366.339746  378.315567  391.906031  404.404981  423.392149
# lw_right          362.442659  373.935424  387.902403  400.019540  417.740240
# tmrt               12.040703   14.453339   17.208549   21.586146   27.927997
# pet                 4.861958    7.564301   10.410688   14.307505   19.030599
# wdir                     NaN         NaN         NaN         NaN         NaN
#
#                           max
# tair_thermohygro    25.053407
# tair_tc1          2047.992188
# tair_tc2          2047.992188
# tair_anemo          30.000000
# rh_thermohygro      87.657969
# ws                  11.009102
# sw_up              712.930225
# sw_down            341.675115
# sw_front           984.895425
# sw_back            866.605546
# sw_left            915.390118
# sw_right           957.943577
# lw_up              457.708289
# lw_down            512.178666
# lw_front           532.448403
# lw_back            479.900517
# lw_left            520.479126
# lw_right           526.091224
# tmrt                73.053752
# pet                 55.898584
# wdir                      NaN

# %%
# Par parcours
by_track = []
for t, g in raw.groupby("track_id"):
    tmp = summary_stats(g, num_cols)
    if "wdir" in METEO:
        tmp.loc["wdir","mean"] = circular_mean_deg(g["wdir"])
    tmp.insert(0, "track_id", t)
    by_track.append(tmp.reset_index(names="variable"))
stats_by_track = pd.concat(by_track, ignore_index=True)
display(stats_by_track)
stats_by_track.to_excel(OUTPUT_DIR / "stats_par_parcours.xlsx", index=False)
# Out:
#             variable  track_id     count  na_pct        mean        std  \
# 0   tair_thermohygro  antigone  121457.0     0.0   14.245584   4.113195
# 1           tair_tc1  antigone  121457.0     0.0   14.160871   4.162505
# 2           tair_tc2  antigone  121457.0     0.0   14.132794   4.132840
# 3         tair_anemo  antigone  121457.0     0.0   16.576262   4.666686
# 4     rh_thermohygro  antigone  121457.0     0.0   68.086875  11.272769
# ..               ...       ...       ...     ...         ...        ...
# 58           lw_left   ecusson  103862.0     0.0  393.476641  23.564546
# 59          lw_right   ecusson  103862.0     0.0  389.145020  23.712800
# 60              tmrt   ecusson  103862.0     0.0   17.696240   7.056153
# 61               pet   ecusson  103862.0     0.0   10.137830   6.079094
# 62              wdir   ecusson       NaN     NaN  355.046212        NaN
#
#            min         p10         p25      median         p75         p90  \
# 0     5.629435    9.148928   10.510796   14.585718   17.122530   19.531167
# 1     5.390625    8.957813   10.570312   14.429688   17.078125   19.304688
# 2     5.367188    9.015625   10.570312   14.359375   17.078125   19.304688
# 3     7.000000   11.000000   12.000000   16.000000   20.000000   23.000000
# 4    41.478447   52.453498   59.320058   67.802167   77.813993   83.217594
# ..         ...         ...         ...         ...         ...         ...
# 58  315.678162  363.104339  377.327544  394.629762  404.009476  427.239592
# 59  313.077331  358.541609  373.179152  390.569285  400.047159  422.843771
# 60    2.424655   11.064358   14.206905   16.600757   19.501914   24.015121
# 61   -5.037205    3.192674    6.530822    9.596329   12.725347   18.595018
# 62         NaN         NaN         NaN         NaN         NaN         NaN
#
#            max
# 0    24.433890
# 1    25.828125
# 2    25.242188
# 3    29.000000
# 4    87.657969
# ..         ...
# 58  520.479126
# 59  526.091224
# 60   68.750711
# 61   50.938198
# 62         NaN
#
# [63 rows x 13 columns]

# %% [markdown]
# ##  Comparaison des parcours : moyennes globales et par créneau horaire
#
# Ce bloc compare les moyennes des variables météo entre trois parcours d’intérêt :
# **Antigone**, **Boulevards** et **Écusson**.
# Une moyenne circulaire est utilisée pour la direction du vent ('wdir'), puis les résultats sont exportés.

# %%
# Sélection des parcours à comparer
tracks_focus = ["antigone", "boulevards", "ecusson"]
sub = raw[raw["track_id"].isin(tracks_focus)]

# Moyennes classiques + moyenne circulaire pour wdir
def means_with_circ(df):
    m = df[num_cols].mean(numeric_only=True)
    if "wdir" in METEO:
        m["wdir"] = circular_mean_deg(df["wdir"])
    return m

# Comparaison globale
comp = sub.groupby("track_id").apply(means_with_circ).T[tracks_focus]
comp.to_excel(OUTPUT_DIR / "comparaison_parcours_moyennes.xlsx")
display(comp)
# Out:
# /tmp/ipython-input-1945564516.py:13: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   comp = sub.groupby("track_id").apply(means_with_circ).T[tracks_focus]
# track_id            antigone  boulevards     ecusson
# tair_thermohygro   14.245584   11.163543   11.367870
# tair_tc1           14.160871   10.977110   39.442929
# tair_tc2           14.132794   10.963355   15.960933
# tair_anemo         16.576262   13.459711   13.377616
# rh_thermohygro     68.086875   57.453884   55.134283
# ws                  1.115083    1.045507    0.971342
# sw_up              69.503826   46.714374   30.146077
# sw_down            11.197564    7.007464    2.380638
# sw_front           68.891622   58.096344   35.275333
# sw_back            46.576064   40.772402   23.655480
# sw_left            42.752374   22.748093   12.230385
# sw_right           75.942138   53.493043   39.335112
# lw_up             366.577550  354.208220  370.062025
# lw_down           401.408397  384.073349  389.980935
# lw_front          395.627175  380.397707  389.149511
# lw_back           394.713319  378.826236  385.837745
# lw_left           399.625614  385.338992  393.476641
# lw_right          394.247870  381.843550  389.145020
# tmrt               22.318479   18.155075   17.696240
# pet                13.676098   10.009802   10.137830
# wdir              358.670545    0.170682  355.046212

# %%
# Comparaison par créneau horaire (M_slot)
comp_M = sub.groupby(["track_id", "M_slot"]).apply(means_with_circ).unstack(0)
comp_M.to_excel(OUTPUT_DIR / "comparaison_parcours_moyennes_par_Mslot.xlsx")
display(comp_M.head())
# Out:
# /tmp/ipython-input-3100739887.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   comp_M = sub.groupby(["track_id", "M_slot"]).apply(means_with_circ).unstack(0)
#          tair_thermohygro                         tair_tc1             \
# track_id         antigone boulevards    ecusson   antigone boulevards
# M_slot
# M1              11.206787   7.660576   8.942756  11.117618   7.333193
# M2              15.129053  12.468959  12.303107  15.161173  12.430946
# M3              16.279904  13.794220  12.728330  16.194290  13.642063
# M4              14.053747  10.998848   9.985556  13.872983  10.721545
#
#                        tair_tc2                       tair_anemo             \
# track_id     ecusson   antigone boulevards    ecusson   antigone boulevards
# M_slot
# M1        157.011741  11.131297   7.387541  33.758839  13.058678   9.680154
# M2         12.253836  15.071895  12.345501  12.098766  18.481574  15.458361
# M3         12.552635  16.129487  13.572954  12.519115  18.773259  16.339291
# M4          9.795978  13.893078  10.765054   9.867012  15.743353  12.755973
#
#                     rh_thermohygro                              ws             \
# track_id    ecusson       antigone boulevards    ecusson  antigone boulevards
# M_slot
# M1        10.636152      78.422463  66.522219  61.346927  0.863910   0.928148
# M2        14.524660      66.763626  54.042821  49.982398  1.057348   1.395283
# M3        15.191265      60.591832  46.796228  47.102115  1.335369   0.964854
# M4        11.687018      66.975029  61.912273  62.375603  1.213080   0.773633
#
#                          sw_up                           sw_down             \
# track_id   ecusson    antigone  boulevards    ecusson   antigone boulevards
# M_slot
# M1        0.801339   48.717718   26.369243  13.970999   5.793217   2.584970
# M2        1.080622  159.649272  114.493248  58.133573  29.662831  21.408082
# M3        0.970403   78.525242   60.004809  38.552957  12.325536   7.053701
# M4        0.935620    0.000000    0.000000   0.000923   0.000000   0.000000
#
#                       sw_front                           sw_back             \
# track_id   ecusson    antigone  boulevards    ecusson   antigone boulevards
# M_slot
# M1        0.534858   58.219302   45.997436  25.328798  37.896765  22.644936
# M2        4.487317  127.627909  115.024761  48.094146  91.995504  95.034469
# M3        2.492398   86.710713   85.115316  36.355007  55.956563  47.528284
# M4        0.000000   14.096395   14.390278  14.111957   3.490550   4.282521
#
#                        sw_left                          sw_right             \
# track_id    ecusson   antigone boulevards    ecusson    antigone boulevards
# M_slot
# M1        14.380907  34.566215  10.441044   3.153325   65.509012  48.432405
# M2        38.068097  89.134463  58.092279  19.104413  135.408363  98.982542
# M3        35.804812  49.966215  29.433111  15.479199   94.537516  62.543484
# M4         3.541104   0.000000   0.000000   0.000000   20.221727  20.652887
#
#                           lw_up                             lw_down  \
# track_id    ecusson    antigone  boulevards     ecusson    antigone
# M_slot
# M1        31.271939  362.681335  346.833615  362.012677  388.799583
# M2        57.594965  371.469616  348.870487  373.189963  407.440311
# M3        48.892422  367.484429  357.706960  371.742765  409.730696
# M4        20.423225  361.450661  353.315464  369.428606  398.289151
#
#                                     lw_front                          \
# track_id  boulevards     ecusson    antigone  boulevards     ecusson
# M_slot
# M1        371.135947  382.923344  385.358779  368.229251  381.479127
# M2        388.144278  393.200840  401.253437  382.573733  392.992274
# M3        393.827844  395.789306  401.963662  388.986783  394.488404
# M4        383.866415  383.417417  391.976673  379.614265  383.809175
#
#              lw_back                             lw_left              \
# track_id    antigone  boulevards     ecusson    antigone  boulevards
# M_slot
# M1        384.648711  365.902906  377.050138  389.414901  372.183546
# M2        400.909044  382.564721  389.896023  405.522931  388.859559
# M3        401.287310  387.951103  391.015087  406.065283  394.555668
# M4        390.147111  377.138851  380.283388  396.268693  384.549191
#
#                         lw_right                               tmrt  \
# track_id     ecusson    antigone  boulevards     ecusson   antigone
# M_slot
# M1        385.884123  383.616588  369.128134  380.896384  19.529653
# M2        397.766758  399.788278  384.580111  392.737310  29.278455
# M3        399.562428  400.585606  390.706583  394.076634  24.892820
# M4        388.030346  390.502187  381.010994  383.350917  16.004968
#
#                                       pet                              wdir  \
# track_id boulevards    ecusson   antigone boulevards    ecusson    antigone
# M_slot
# M1        14.515659  15.177990  10.842659   6.703842   7.869711  358.725688
# M2        24.188712  20.015502  16.860707  12.433204  11.427057    2.255707
# M3        21.239010  19.369810  15.591107  13.057286  11.639299  358.371773
# M4        13.951566  14.613575  11.282775   8.859926   8.170099  357.249837
#
#
# track_id  boulevards     ecusson
# M_slot
# M1          6.154562  356.155171
# M2          4.504606  356.157187
# M3          2.949620  357.070572
# M4        359.416980  355.072905

# %% [markdown]
# ##  Statistiques par parcours et par passage ('passage_slot')
#
# Ce bloc calcule, pour chaque parcours et chaque passage (M1–M4), la **moyenne** et la **médiane** de chaque variable météo, ainsi que la **moyenne circulaire** pour la direction du vent ('wdir').

# %%
# Fonction d’agrégation : moyenne + médiane (et moyenne circulaire pour wdir)
def agg_fun(g):
    out = {}
    for c in num_cols:
        out[c + "_mean"] = g[c].mean()
        out[c + "_median"] = g[c].median()
    if "wdir" in METEO:
        out["wdir_mean_circ"] = circular_mean_deg(g["wdir"])
    return pd.Series(out)

# Application du calcul par parcours et par passage
stats_track_passage = raw.groupby(["track_id", "passage_slot"]).apply(agg_fun).reset_index()

display(stats_track_passage)

# Sauvegarde des résultats
stats_track_passage.to_excel(OUTPUT_DIR / "stats_parcours_par_passage.xlsx", index=False)
# Out:
# /tmp/ipython-input-3102823500.py:12: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   stats_track_passage = raw.groupby(["track_id", "passage_slot"]).apply(agg_fun).reset_index()
#       track_id passage_slot  tair_thermohygro_mean  tair_thermohygro_median  \
# 0     antigone           M1              11.206787                 9.709697
# 1     antigone           M2              15.129053                14.991608
# 2     antigone           M3              16.279904                15.958267
# 3     antigone           M4              14.053747                14.222553
# 4   boulevards           M1               7.660576                 7.803082
# 5   boulevards           M2              12.468959                12.129015
# 6   boulevards           M3              13.794220                13.629740
# 7   boulevards           M4              10.998848                10.916686
# 8      ecusson           M1               8.942756                10.046159
# 9      ecusson           M2              12.303107                13.165103
# 10     ecusson           M3              12.728330                12.433433
# 11     ecusson           M4               9.985556                10.131609
#
#     tair_tc1_mean  tair_tc1_median  tair_tc2_mean  tair_tc2_median  \
# 0       11.117618         9.625000      11.131297         9.671875
# 1       15.161173        15.023438      15.071895        14.648438
# 2       16.194290        15.890625      16.129487        15.882812
# 3       13.872983        14.078125      13.893078        14.085938
# 4        7.333193         7.562500       7.387541         7.632812
# 5       12.430946        12.062500      12.345501        12.015625
# 6       13.642063        13.554688      13.572954        13.539062
# 7       10.721545        10.414062      10.765054        10.500000
# 8      157.011741        10.484375      33.758839         9.984375
# 9       12.253836        13.101562      12.098766        13.085938
# 10      12.552635        12.304688      12.519115        12.382812
# 11       9.795978        10.062500       9.867012        10.218750
#
#     tair_anemo_mean  tair_anemo_median  rh_thermohygro_mean  \
# 0         13.058678               12.0            78.422463
# 1         18.481574               19.0            66.763626
# 2         18.773259               19.0            60.591832
# 3         15.743353               16.0            66.975029
# 4          9.680154               10.0            66.522219
# 5         15.458361               15.0            54.042821
# 6         16.339291               16.0            46.796228
# 7         12.755973               12.0            61.912273
# 8         10.636152               11.0            61.346927
# 9         14.524660               15.0            49.982398
# 10        15.191265               15.0            47.102115
# 11        11.687018               11.0            62.375603
#
#     rh_thermohygro_median   ws_mean  ws_median  sw_up_mean  sw_up_median  \
# 0               79.959792  0.863910   0.823110   48.717718     29.365157
# 1               66.943847  1.057348   0.977444  159.649272    102.973417
# 2               59.835050  1.335369   1.080332   78.525242     54.587744
# 3               63.850080  1.213080   0.823110    0.000000      0.000000
# 4               67.960479  0.928148   0.720222   26.369243     12.155650
# 5               53.582666  1.395283   1.080332  114.493248     58.813002
# 6               46.164874  0.964854   0.823110   60.004809     36.521361
# 7               59.960937  0.773633   0.720222    0.000000      0.000000
# 8               58.667735  0.801339   0.720222   13.970999      7.107790
# 9               47.860533  1.080622   0.874555   58.133573     38.135716
# 10              47.757534  0.970403   0.823110   38.552957     19.491369
# 11              73.565309  0.935620   0.720222    0.000923      0.000000
#
#     sw_down_mean  sw_down_median  sw_front_mean  sw_front_median  \
# 0       5.793217        0.000000      58.219302        32.354190
# 1      29.662831       10.146091     127.627909        70.930541
# 2      12.325536        0.306412      86.710713        47.948820
# 3       0.000000        0.000000      14.096395        14.427071
# 4       2.584970        0.000000      45.997436        23.107944
# 5      21.408082        0.838924     115.024761        57.203393
# 6       7.053701        0.000000      85.115316        39.918344
# 7       0.000000        0.000000      14.390278        14.453367
# 8       0.534858        0.000000      25.328798        19.860341
# 9       4.487317        0.000000      48.094146        34.091504
# 10      2.492398        0.000000      36.355007        26.056207
# 11      0.000000        0.000000      14.111957        14.289453
#
#     sw_back_mean  sw_back_median  sw_left_mean  sw_left_median  sw_right_mean  \
# 0      37.896765       18.491788     34.566215        7.902942      65.509012
# 1      91.995504       52.283107     89.134463       48.466318     135.408363
# 2      55.956563       34.545951     49.966215       22.222741      94.537516
# 3       3.490550        4.202142      0.000000        0.000000      20.221727
# 4      22.644936       11.442799     10.441044        0.000000      48.432405
# 5      95.034469       35.719118     58.092279       28.625726      98.982542
# 6      47.528284       29.822402     29.433111       17.589185      62.543484
# 7       4.282521        4.301609      0.000000        0.000000      20.652887
# 8      14.380907        9.248165      3.153325        0.000000      31.271939
# 9      38.068097       22.963263     19.104413        4.475909      57.594965
# 10     35.804812       15.375153     15.479199        0.000000      48.892422
# 11      3.541104        3.921454      0.000000        0.000000      20.423225
#
#     sw_right_median  lw_up_mean  lw_up_median  lw_down_mean  lw_down_median  \
# 0         37.859535  362.681335    363.033753    388.799583      381.445430
# 1         73.914154  371.469616    371.317549    407.440311      399.534668
# 2         52.359981  367.484429    370.465953    409.730696      404.594690
# 3         20.629417  361.450661    361.058075    398.289151      393.723386
# 4         26.897837  346.833615    348.333499    371.135947      371.285462
# 5         50.248323  348.870487    351.912074    388.144278      387.275422
# 6         40.399954  357.706960    360.029557    393.827844      393.042439
# 7         20.680579  353.315464    355.865660    383.866415      382.970096
# 8         24.623639  362.012677    365.934205    382.923344      383.469327
# 9         35.631065  373.189963    374.071082    393.200840      394.159110
# 10        29.964360  371.742765    372.523748    395.789306      395.867318
# 11        20.542714  369.428606    378.648209    383.417417      390.169144
#
#     lw_front_mean  lw_front_median  lw_back_mean  lw_back_median  \
# 0      385.358779       381.320419    384.648711      381.377409
# 1      401.253437       396.323706    400.909044      395.889982
# 2      401.963662       399.581289    401.287310      398.325230
# 3      391.976673       389.051568    390.147111      387.175416
# 4      368.229251       369.274107    365.902906      366.465739
# 5      382.573733       382.740887    382.564721      381.626918
# 6      388.986783       388.310854    387.951103      387.232266
# 7      379.614265       380.146626    377.138851      376.867021
# 8      381.479127       382.323114    377.050138      377.261385
# 9      392.992274       394.332912    389.896023      391.548768
# 10     394.488404       394.351059    391.015087      390.255470
# 11     383.809175       390.373002    380.283388      386.225985
#
#     lw_left_mean  lw_left_median  lw_right_mean  lw_right_median  tmrt_mean  \
# 0     389.414901      385.355518     383.616588       379.747035  19.529653
# 1     405.522931      399.932793     399.788278       394.816819  29.278455
# 2     406.065283      404.053082     400.585606       398.133425  24.892820
# 3     396.268693      392.885583     390.502187       387.741452  16.004968
# 4     372.183546      374.211569     369.128134       371.363638  14.515659
# 5     388.859559      389.033078     384.580111       385.226051  24.188712
# 6     394.555668      395.338094     390.706583       391.748117  21.239010
# 7     384.549191      385.051551     381.010994       382.188355  13.951566
# 8     385.884123      386.392681     380.896384       381.329654  15.177990
# 9     397.766758      399.244066     392.737310       394.797791  20.015502
# 10    399.562428      398.837466     394.076634       393.467257  19.369810
# 11    388.030346      393.676967     383.350917       389.404911  14.613575
#
#     tmrt_median   pet_mean  pet_median  wdir_mean_circ
# 0     15.899973  10.842659    9.318879      358.725688
# 1     24.973208  16.860707   15.226830        2.255707
# 2     21.994276  15.591107   13.723872      358.371773
# 3     15.448150  11.282775   10.644625      357.249837
# 4     13.406846   6.703842    6.200501        6.154562
# 5     19.896619  12.433204   11.341008        4.504606
# 6     19.265050  13.057286   12.414780        2.949620
# 7     14.107990   8.859926    8.759664      359.416980
# 8     14.876727   7.869711    8.146820      356.155171
# 9     18.727303  11.427057   10.785115      356.157187
# 10    18.363512  11.639299   10.255348      357.070572
# 11    15.833160   8.170099    8.534037      355.072905

# %% [markdown]
# ##  Matrices de corrélation par parcours
#
# Ce bloc calcule et affiche les **corrélations entre les variables numériques**  pour chaque parcours ('track_id').
# Les résultats sont également enregistrés sous forme d’images dans la branche 'figures/'.

# %%
for t, g in raw.groupby("track_id"):
    # Sélection des variables numériques pertinentes
    sel = g[num_cols].select_dtypes(include=[np.number]).dropna(how="all", axis=1)

    if sel.shape[1] < 2:
        print(f"Parcours {t} : pas assez de colonnes numériques pour corrélation.")
        continue

    # Calcul de la matrice de corrélation
    corr = sel.corr()

    # Visualisation
    plt.figure(figsize=(9, 6))
    plt.title(f"Corrélations — {t}")
    plt.imshow(corr, aspect="auto")
    plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
    plt.yticks(range(len(corr.index)), corr.index)
    plt.colorbar(label="r")
    plt.tight_layout()

    # Sauvegarde et affichage
    plt.savefig(FIG_DIR / f"corr_{t}.png", dpi=150)
    plt.show()

# %% [markdown]
# ##  Distribution des variables météo par parcours
#
# Ce bloc affiche des **boxplots** (boîtes à moustaches) pour comparer la distribution de plusieurs variables météorologiques clés (`tair_thermohygro`, `tmrt`, `rh_thermohygro`, `ws`, `pet`) entre les différents parcours (`track_id`).

# %%
# Variables météo à visualiser
vars_plot = [v for v in ["tair_thermohygro", "tmrt", "rh_thermohygro", "ws", "pet"] if v in METEO]

for v in vars_plot:
    plt.figure(figsize=(7, 4))
    raw.boxplot(column=v, by="track_id", grid=False)
    plt.title(f"{v} par parcours")
    plt.suptitle("")  # supprime le titre automatique de pandas
    plt.xlabel("Parcours")
    plt.ylabel(v)
    plt.tight_layout()

    # Sauvegarde du graphique
    plt.savefig(FIG_DIR / f"box_{v}_parcours.png", dpi=150)
    plt.show()

# %% [markdown]
# ## Distribution globale des variables météo
#
# Ce bloc trace un **histogramme** pour chaque variable météo disponible, afin de visualiser la **répartition des valeurs mesurées** (et détecter d’éventuels biais ou valeurs extrêmes).

# %%
for v in METEO:
    s = raw[v].dropna()
    if len(s) == 0:
        continue

    plt.figure(figsize=(6, 4))
    plt.hist(s, bins=50)
    plt.title(f"Distribution — {v}")
    plt.xlabel(v)
    plt.ylabel("Fréquence")
    plt.tight_layout()

    # Sauvegarde et affichage
    plt.savefig(FIG_DIR / f"dist_global_{v}.png", dpi=150)
    plt.show()

# %% [markdown]
# ## Moyennes et intervalles de confiance (IC95%) par parcours
#
# Ce bloc calcule la **moyenne** et l’**intervalle de confiance à 95 %** pour chaque variable météo et chaque parcours (`track_id`).
# Les résultats sont visualisés sous forme de points avec barres d’erreur.

# %%
# Calcul des moyennes, écarts-types et effectifs par parcours
g = raw.groupby("track_id")[num_cols].agg(["mean", "std", "count"])

# Tracé des moyennes avec intervalles de confiance
for v in num_cols:
    m = g[(v, "mean")]
    se = g[(v, "std")] / np.sqrt(g[(v, "count")])
    ic = 1.96 * se  # Intervalle de confiance à 95 %

    plt.figure(figsize=(7, 4))
    plt.errorbar(m.index.astype(str), m.values, yerr=ic.values, fmt="o", capsize=4)
    plt.title(f"Moyenne ± IC95% — {v}")
    plt.xlabel("Parcours")
    plt.ylabel(v)
    plt.tight_layout()

    # Sauvegarde et affichage
    plt.savefig(FIG_DIR / f"mean_ic_{v}_parcours.png", dpi=150)
    plt.show()

# %% [markdown]
# ##  Profil des variables météo selon le moment de la journée (M1–M4)
#
# Ce bloc trace, pour chaque variable météo et pour les parcours principaux (**Antigone**, **Boulevards**, **Écusson**), l’évolution moyenne des valeurs selon les quatre créneaux horaires de mesure (`M1` à `M4`).

# %%
# Ordre des créneaux horaires
order = ["M1", "M2", "M3", "M4"]

# Moyenne des variables par parcours et créneau
agg = raw.groupby(["track_id", "M_slot"])[num_cols].mean().reset_index()

# Parcours à comparer
tracks_focus = ["antigone", "boulevards", "ecusson"]

# Tracé des profils journaliers
for v in num_cols:
    plt.figure(figsize=(7, 4))
    for t in tracks_focus:
        gg = agg[agg.track_id == t].set_index("M_slot").reindex(order)[v]
        if gg.isna().all():
            continue
        plt.plot(order, gg.values, marker="o", label=t)

    plt.title(f"Profil {v} — M1..M4")
    plt.xlabel("Créneau horaire")
    plt.ylabel(v)
    plt.legend()
    plt.tight_layout()

    # Sauvegarde et affichage
    plt.savefig(FIG_DIR / f"profile_{v}_Mslots.png", dpi=150)
    plt.show()

# %% [markdown]
# ## Moyenne des variables météo par parcours
#
# Ce bloc compare la **moyenne des variables météorologiques** principales entre les trois parcours étudiés : **Antigone**, **Boulevards** et **Écusson**.Les résultats sont présentés sous forme d’histogrammes.

# %%
# Sélection des parcours d'intérêt et calcul des moyennes
comp = (raw[raw["track_id"].isin(["antigone", "boulevards", "ecusson"])]
          .groupby("track_id")[num_cols]
          .mean()
          .T)

# Tracé des moyennes par variable
for v in comp.index:
    plt.figure(figsize=(6, 4))
    plt.bar(comp.columns.astype(str), comp.loc[v].values)
    plt.title(f"Moyenne par parcours — {v}")
    plt.xlabel("Parcours")
    plt.ylabel(v)
    plt.tight_layout()

    # Sauvegarde et affichage
    plt.savefig(FIG_DIR / f"bar_mean_{v}_parcours.png", dpi=150)
    plt.show()

# %% [markdown]
# ##  Visualisation spatiale de la température de l’air
#
# Ce bloc trace la **position GPS** des points de mesure (`lon`, `lat`) et colore les points selon la **température de l’air (`tair_thermohygro`)** pour chaque parcours. Cela permet de visualiser les variations de température le long du trajet.

# %%
# Vérifie la présence des colonnes nécessaires avant de tracer
if {"lat", "lon"}.issubset(raw.columns) and "tair_thermohygro" in raw.columns:
    # Boucle sur chaque parcours
    for t, g in raw.groupby("track_id"):
        s = g.dropna(subset=["lat", "lon", "tair_thermohygro"])
        if s.empty:
            continue
        plt.figure(figsize=(6, 6))
        plt.scatter(s["lon"], s["lat"], c=s["tair_thermohygro"], s=4)
        plt.title(f"Trace {t} — color: tair_thermohygro")
        plt.xlabel("Longitude")
        plt.ylabel("Latitude")
        plt.tight_layout()
        plt.savefig(FIG_DIR / f"map_tair_{t}.png", dpi=150)
        plt.show()

# %% [markdown]
# # Task
# Analyze the provided dataset to identify and handle illogical zero values in numerical columns, following the steps outlined in the user's message regarding identifying problematic variables, distinguishing true zeros from false ones based on physical context, and deciding on appropriate correction strategies (replacing with NaN for isolated errors, considering imputation for moderate occurrences). Document the findings and corrections made.

# %% [markdown]
# ## Identify variables with a significant percentage of zero values
#
# ### Subtask:
# Calculate the proportion of zero values for each numerical column.

# %% [markdown]
# **Reasoning**:
# Calculate and display the percentage of zero values for each numerical column in the `raw` DataFrame, sorting by percentage in descending order.

# %%
# Create a list of numerical columns
numerical_cols = raw.select_dtypes(include=np.number).columns.tolist()

# Filter the DataFrame for the 'antigone' track
df_antigone = raw[raw['track_id'] == 'antigone'].copy()

# Calculate zero percentages for the 'antigone' track
zero_percentages_antigone = {}
for col in numerical_cols:
    total_non_missing = df_antigone[col].count()
    if total_non_missing > 0:
        zero_count = (df_antigone[col] == 0).sum()
        zero_percentage = (zero_count / total_non_missing) * 100
        zero_percentages_antigone[col] = zero_percentage
    else:
        zero_percentages_antigone[col] = 0


# Sort by zero percentage in descending order
sorted_zero_percentages_antigone = sorted(zero_percentages_antigone.items(), key=lambda item: item[1], reverse=True)

# Display the sorted percentages
print("Percentage of zero values for numerical columns in 'antigone' track:")
for col, percentage in sorted_zero_percentages_antigone:
    print(f"{col}: {percentage:.2f}%")
# Out:
# Percentage of zero values for numerical columns in 'antigone' track:
# sw_up: 26.23%
# ws: 2.78%
# sw_back: 2.74%
# wdir: 0.31%
# sw_right: 0.00%
# section_id: 0.00%
# segment_id: 0.00%
# point_id: 0.00%
# section_duration: 0.00%
# section_speed: 0.00%
# gnss_accuracy: 0.00%
# lon_ontrack: 0.00%
# lat_ontrack: 0.00%
# lon_rtk: 0.00%
# lat_rtk: 0.00%
# sun_azimuth: 0.00%
# sun_height: 0.00%
# tair_thermohygro: 0.00%
# tair_tc1: 0.00%
# tair_tc2: 0.00%
# tair_anemo: 0.00%
# rh_thermohygro: 0.00%
# sw_front: 0.00%
# lw_up: 0.00%
# lw_down: 0.00%
# lw_front: 0.00%
# lw_back: 0.00%
# lw_left: 0.00%
# lw_right: 0.00%
# tmrt: 0.00%
# pet: 0.00%
# lon: 0.00%
# lat: 0.00%

# %%
# Filter for numerical columns with zero percentage greater than 0 in antigone track
variables_with_zeros_antigone = [col for col, percentage in sorted_zero_percentages_antigone if percentage > 0]

# Display index, timestamp, M_slot, and the variable value for zero values in these variables for antigone track
print("Index, Timestamp, M_slot, and Value of Zero Values in 'antigone' track (for variables with > 0% zeros):")
for col in variables_with_zeros_antigone:
    zero_indices = df_antigone[df_antigone[col] == 0].index
    if not zero_indices.empty:
        print(f"\nVariable: {col}")
        # Displaying 'timestamp', 'M_slot', and the column with zero values
        display(df_antigone.loc[zero_indices, ['timestamp', 'M_slot', col]])
# Out:
# Index, Timestamp, M_slot, and Value of Zero Values in 'antigone' track (for variables with > 0% zeros):
#
# Variable: sw_down
#                  timestamp M_slot  sw_down
# 0      2024-10-29 08:36:30     M1      0.0
# 1      2024-10-29 08:36:31     M1      0.0
# 2      2024-10-29 08:36:32     M1      0.0
# 3      2024-10-29 08:36:33     M1      0.0
# 4      2024-10-29 08:36:34     M1      0.0
# ...                    ...    ...      ...
# 121452 2025-09-01 19:08:16    NaN      0.0
# 121453 2025-09-01 19:08:17    NaN      0.0
# 121454 2025-09-01 19:08:18    NaN      0.0
# 121455 2025-09-01 19:08:19    NaN      0.0
# 121456 2025-09-01 19:08:20    NaN      0.0
#
# [78789 rows x 3 columns]
# Variable: sw_left
#                  timestamp M_slot  sw_left
# 55     2024-10-29 08:37:28     M1      0.0
# 61     2024-10-29 08:37:34     M1      0.0
# 62     2024-10-29 08:37:35     M1      0.0
# 63     2024-10-29 08:37:36     M1      0.0
# 64     2024-10-29 08:37:37     M1      0.0
# ...                    ...    ...      ...
# 121452 2025-09-01 19:08:16    NaN      0.0
# 121453 2025-09-01 19:08:17    NaN      0.0
# 121454 2025-09-01 19:08:18    NaN      0.0
# 121455 2025-09-01 19:08:19    NaN      0.0
# 121456 2025-09-01 19:08:20    NaN      0.0
#
# [40933 rows x 3 columns]
# Variable: sw_up
#                  timestamp M_slot  sw_up
# 71     2024-10-29 08:37:44     M1    0.0
# 74     2024-10-29 08:37:47     M1    0.0
# 111    2024-10-29 08:38:24     M1    0.0
# 12808  2024-10-29 17:30:04     M4    0.0
# 12809  2024-10-29 17:30:05     M4    0.0
# ...                    ...    ...    ...
# 121452 2025-09-01 19:08:16    NaN    0.0
# 121453 2025-09-01 19:08:17    NaN    0.0
# 121454 2025-09-01 19:08:18    NaN    0.0
# 121455 2025-09-01 19:08:19    NaN    0.0
# 121456 2025-09-01 19:08:20    NaN    0.0
#
# [31856 rows x 3 columns]
# Variable: ws
#                  timestamp M_slot   ws
# 186    2024-10-29 08:40:00     M1  0.0
# 479    2024-10-29 08:46:19     M1  0.0
# 480    2024-10-29 08:46:20     M1  0.0
# 481    2024-10-29 08:46:21     M1  0.0
# 482    2024-10-29 08:46:22     M1  0.0
# ...                    ...    ...  ...
# 120039 2025-09-01 18:41:20     M4  0.0
# 120577 2025-09-01 18:51:34     M4  0.0
# 120581 2025-09-01 18:51:38     M4  0.0
# 120583 2025-09-01 18:51:40     M4  0.0
# 120615 2025-09-01 18:52:12     M4  0.0
#
# [3378 rows x 3 columns]
# Variable: sw_back
#                  timestamp M_slot  sw_back
# 71     2024-10-29 08:37:44     M1      0.0
# 73     2024-10-29 08:37:46     M1      0.0
# 74     2024-10-29 08:37:47     M1      0.0
# 92     2024-10-29 08:38:05     M1      0.0
# 106    2024-10-29 08:38:19     M1      0.0
# ...                    ...    ...      ...
# 108036 2025-09-01 09:50:55     M1      0.0
# 108043 2025-09-01 09:51:02     M1      0.0
# 108071 2025-09-01 09:51:30     M1      0.0
# 108176 2025-09-01 09:53:23     M1      0.0
# 108186 2025-09-01 09:53:33     M1      0.0
#
# [3326 rows x 3 columns]
# Variable: wdir
#                  timestamp M_slot  wdir
# 1237   2024-10-29 09:01:26     M1     0
# 1238   2024-10-29 09:01:27     M1     0
# 1330   2024-10-29 09:03:09     M1     0
# 4186   2024-10-29 10:03:09    NaN     0
# 4557   2024-10-29 11:35:38     M2     0
# ...                    ...    ...   ...
# 121177 2025-09-01 19:02:22    NaN     0
# 121210 2025-09-01 19:03:01    NaN     0
# 121222 2025-09-01 19:03:13    NaN     0
# 121269 2025-09-01 19:04:01    NaN     0
# 121272 2025-09-01 19:04:04    NaN     0
#
# [379 rows x 3 columns]
# Variable: sw_right
#                  timestamp M_slot  sw_right
# 104302 2025-09-01 08:35:52     M1       0.0

# %%
# Create a list of numerical columns
numerical_cols = raw.select_dtypes(include=np.number).columns.tolist()

# Filter the DataFrame for the 'ecusson' track
df_ecusson = raw[raw['track_id'] == 'ecusson'].copy()

# Calculate zero percentages for the 'ecusson' track
zero_percentages_ecusson = {}
for col in numerical_cols:
    total_non_missing = df_ecusson[col].count()
    if total_non_missing > 0:
        zero_count = (df_ecusson[col] == 0).sum()
        zero_percentage = (zero_count / total_non_missing) * 100
        zero_percentages_ecusson[col] = zero_percentage
    else:
        zero_percentages_ecusson[col] = 0


# Sort by zero percentage in descending order
sorted_zero_percentages_ecusson = sorted(zero_percentages_ecusson.items(), key=lambda item: item[1], reverse=True)

# Display the sorted percentages
print("Percentage of zero values for numerical columns in 'ecusson' track:")
for col, percentage in sorted_zero_percentages_ecusson:
    print(f"{col}: {percentage:.2f}%")
# Out:
# Percentage of zero values for numerical columns in 'ecusson' track:
# sw_up: 24.52%
# ws: 4.63%
# tair_tc2: 1.94%
# wdir: 0.68%
# sw_back: 0.65%
# section_id: 0.00%
# segment_id: 0.00%
# point_id: 0.00%
# section_duration: 0.00%
# section_speed: 0.00%
# gnss_accuracy: 0.00%
# lon_ontrack: 0.00%
# lat_ontrack: 0.00%
# lon_rtk: 0.00%
# lat_rtk: 0.00%
# sun_azimuth: 0.00%
# sun_height: 0.00%
# tair_thermohygro: 0.00%
# tair_tc1: 0.00%
# tair_anemo: 0.00%
# rh_thermohygro: 0.00%
# sw_front: 0.00%
# sw_right: 0.00%
# lw_up: 0.00%
# lw_down: 0.00%
# lw_front: 0.00%
# lw_back: 0.00%
# lw_left: 0.00%
# lw_right: 0.00%
# tmrt: 0.00%
# pet: 0.00%
# lon: 0.00%
# lat: 0.00%

# %%
# Filter for numerical columns with zero percentage greater than 0 in ecusson track
variables_with_zeros_ecusson = [col for col, percentage in sorted_zero_percentages_ecusson if percentage > 0]

# Display index, timestamp, M_slot, and the variable value for zero values in these variables for antigone track
print("Index, Timestamp, M_slot, and Value of Zero Values in 'ecusson' track (for variables with > 0% zeros):")
for col in variables_with_zeros_ecusson:
    zero_indices = df_ecusson[df_ecusson[col] == 0].index
    if not zero_indices.empty:
        print(f"\nVariable: {col}")
        # Displaying 'timestamp', 'M_slot', and the column with zero values
        display(df_ecusson.loc[zero_indices, ['timestamp', 'M_slot', col]])
# Out:
# Index, Timestamp, M_slot, and Value of Zero Values in 'ecusson' track (for variables with > 0% zeros):
#
# Variable: sw_down
#                  timestamp M_slot  sw_down
# 237419 2024-10-31 08:30:13     M1      0.0
# 237420 2024-10-31 08:30:14     M1      0.0
# 237421 2024-10-31 08:30:15     M1      0.0
# 237422 2024-10-31 08:30:16     M1      0.0
# 237423 2024-10-31 08:30:17     M1      0.0
# ...                    ...    ...      ...
# 341276 2025-01-14 19:18:24    NaN      0.0
# 341277 2025-01-14 19:18:25    NaN      0.0
# 341278 2025-01-14 19:18:26    NaN      0.0
# 341279 2025-01-14 19:18:27    NaN      0.0
# 341280 2025-01-14 19:18:28    NaN      0.0
#
# [93349 rows x 3 columns]
# Variable: sw_left
#                  timestamp M_slot  sw_left
# 237533 2024-10-31 08:32:21     M1      0.0
# 237542 2024-10-31 08:32:30     M1      0.0
# 237543 2024-10-31 08:32:31     M1      0.0
# 237544 2024-10-31 08:32:32     M1      0.0
# 237545 2024-10-31 08:32:33     M1      0.0
# ...                    ...    ...      ...
# 341276 2025-01-14 19:18:24    NaN      0.0
# 341277 2025-01-14 19:18:25    NaN      0.0
# 341278 2025-01-14 19:18:26    NaN      0.0
# 341279 2025-01-14 19:18:27    NaN      0.0
# 341280 2025-01-14 19:18:28    NaN      0.0
#
# [68797 rows x 3 columns]
# Variable: sw_up
#                  timestamp M_slot  sw_up
# 237726 2024-10-31 08:36:25     M1    0.0
# 237736 2024-10-31 08:36:35     M1    0.0
# 237916 2024-10-31 08:40:34     M1    0.0
# 239087 2024-10-31 09:12:09     M1    0.0
# 239092 2024-10-31 09:12:14     M1    0.0
# ...                    ...    ...    ...
# 341276 2025-01-14 19:18:24    NaN    0.0
# 341277 2025-01-14 19:18:25    NaN    0.0
# 341278 2025-01-14 19:18:26    NaN    0.0
# 341279 2025-01-14 19:18:27    NaN    0.0
# 341280 2025-01-14 19:18:28    NaN    0.0
#
# [25465 rows x 3 columns]
# Variable: ws
#                  timestamp M_slot   ws
# 237426 2024-10-31 08:30:20     M1  0.0
# 237427 2024-10-31 08:30:21     M1  0.0
# 237428 2024-10-31 08:30:22     M1  0.0
# 237435 2024-10-31 08:30:29     M1  0.0
# 237436 2024-10-31 08:30:30     M1  0.0
# ...                    ...    ...  ...
# 341169 2025-01-14 19:16:16    NaN  0.0
# 341170 2025-01-14 19:16:17    NaN  0.0
# 341171 2025-01-14 19:16:18    NaN  0.0
# 341172 2025-01-14 19:16:19    NaN  0.0
# 341173 2025-01-14 19:16:20    NaN  0.0
#
# [4814 rows x 3 columns]
# Variable: tair_tc2
#                  timestamp M_slot  tair_tc2
# 320181 2025-01-14 08:32:43     M1       0.0
# 320182 2025-01-14 08:32:44     M1       0.0
# 320183 2025-01-14 08:32:45     M1       0.0
# 320184 2025-01-14 08:32:46     M1       0.0
# 320185 2025-01-14 08:32:47     M1       0.0
# ...                    ...    ...       ...
# 326561 2025-01-14 11:49:04     M2       0.0
# 326562 2025-01-14 11:49:05     M2       0.0
# 326563 2025-01-14 11:49:06     M2       0.0
# 326564 2025-01-14 11:49:07     M2       0.0
# 326565 2025-01-14 11:49:08     M2       0.0
#
# [2011 rows x 3 columns]
# Variable: wdir
#                  timestamp M_slot  wdir
# 237765 2024-10-31 08:37:16     M1     0
# 237776 2024-10-31 08:37:27     M1     0
# 239670 2024-10-31 09:24:33     M1     0
# 239671 2024-10-31 09:24:34     M1     0
# 239688 2024-10-31 09:24:51     M1     0
# ...                    ...    ...   ...
# 335714 2025-01-14 16:17:50    NaN     0
# 335715 2025-01-14 16:17:51    NaN     0
# 335718 2025-01-14 16:17:54    NaN     0
# 336938 2025-01-14 17:45:09     M4     0
# 336939 2025-01-14 17:45:10     M4     0
#
# [711 rows x 3 columns]
# Variable: sw_back
#                  timestamp M_slot  sw_back
# 237702 2024-10-31 08:36:01     M1      0.0
# 237726 2024-10-31 08:36:25     M1      0.0
# 237736 2024-10-31 08:36:35     M1      0.0
# 237742 2024-10-31 08:36:41     M1      0.0
# 237788 2024-10-31 08:38:07     M1      0.0
# ...                    ...    ...      ...
# 278839 2024-11-21 19:04:18    NaN      0.0
# 279163 2024-11-21 19:10:07    NaN      0.0
# 279218 2024-11-21 19:11:04    NaN      0.0
# 279365 2024-11-21 19:13:50    NaN      0.0
# 279404 2024-11-21 19:14:35    NaN      0.0
#
# [674 rows x 3 columns]

# %%
# Create a list of numerical columns
numerical_cols = raw.select_dtypes(include=np.number).columns.tolist()

# Filter the DataFrame for the 'boulevards' track
df_boulevards = raw[raw['track_id'] == 'boulevards'].copy()

# Calculate zero percentages for the 'boulevards' track
zero_percentages_boulevards = {}
for col in numerical_cols:
    total_non_missing = df_boulevards[col].count()
    if total_non_missing > 0:
        zero_count = (df_boulevards[col] == 0).sum()
        zero_percentage = (zero_count / total_non_missing) * 100
        zero_percentages_boulevards[col] = zero_percentage
    else:
        zero_percentages_antigone[col] = 0


# Sort by zero percentage in descending order
sorted_zero_percentages_boulevards = sorted(zero_percentages_boulevards.items(), key=lambda item: item[1], reverse=True)

# Display the sorted percentages
print("Percentage of zero values for numerical columns in 'antigone' track:")
for col, percentage in sorted_zero_percentages_boulevards:
    print(f"{col}: {percentage:.2f}%")
# Out:
# Percentage of zero values for numerical columns in 'antigone' track:
# sw_up: 27.11%
# ws: 5.02%
# wdir: 0.66%
# section_id: 0.00%
# segment_id: 0.00%
# point_id: 0.00%
# section_duration: 0.00%
# section_speed: 0.00%
# gnss_accuracy: 0.00%
# lon_ontrack: 0.00%
# lat_ontrack: 0.00%
# lon_rtk: 0.00%
# lat_rtk: 0.00%
# sun_azimuth: 0.00%
# sun_height: 0.00%
# tair_thermohygro: 0.00%
# tair_tc1: 0.00%
# tair_tc2: 0.00%
# tair_anemo: 0.00%
# rh_thermohygro: 0.00%
# sw_front: 0.00%
# sw_back: 0.00%
# sw_right: 0.00%
# lw_up: 0.00%
# lw_down: 0.00%
# lw_front: 0.00%
# lw_back: 0.00%
# lw_left: 0.00%
# lw_right: 0.00%
# tmrt: 0.00%
# pet: 0.00%
# lon: 0.00%
# lat: 0.00%

# %%
# Filter for numerical columns with zero percentage greater than 0 in antigone track
variables_with_zeros_boulevards = [col for col, percentage in sorted_zero_percentages_boulevards if percentage > 0]

# Display index, timestamp, M_slot, and the variable value for zero values in these variables for boulevards track
print("Index, Timestamp, M_slot, and Value of Zero Values in 'boulevards' track (for variables with > 0% zeros):")
for col in variables_with_zeros_boulevards:
    zero_indices = df_boulevards[df_boulevards[col] == 0].index
    if not zero_indices.empty:
        print(f"\nVariable: {col}")
        # Displaying 'timestamp', 'M_slot', and the column with zero values
        display(df_boulevards.loc[zero_indices, ['timestamp', 'M_slot', col]])
# Out:
# Index, Timestamp, M_slot, and Value of Zero Values in 'boulevards' track (for variables with > 0% zeros):
#
# Variable: sw_down
#                  timestamp M_slot  sw_down
# 121457 2024-11-14 08:30:24     M1      0.0
# 121458 2024-11-14 08:30:25     M1      0.0
# 121459 2024-11-14 08:30:26     M1      0.0
# 121460 2024-11-14 08:30:27     M1      0.0
# 121461 2024-11-14 08:30:28     M1      0.0
# ...                    ...    ...      ...
# 237414 2025-01-16 19:26:37    NaN      0.0
# 237415 2025-01-16 19:26:38    NaN      0.0
# 237416 2025-01-16 19:26:39    NaN      0.0
# 237417 2025-01-16 19:26:40    NaN      0.0
# 237418 2025-01-16 19:26:41    NaN      0.0
#
# [87746 rows x 3 columns]
# Variable: sw_left
#                  timestamp M_slot  sw_left
# 121457 2024-11-14 08:30:24     M1      0.0
# 121458 2024-11-14 08:30:25     M1      0.0
# 121459 2024-11-14 08:30:26     M1      0.0
# 121460 2024-11-14 08:30:27     M1      0.0
# 121461 2024-11-14 08:30:28     M1      0.0
# ...                    ...    ...      ...
# 237414 2025-01-16 19:26:37    NaN      0.0
# 237415 2025-01-16 19:26:38    NaN      0.0
# 237416 2025-01-16 19:26:39    NaN      0.0
# 237417 2025-01-16 19:26:40    NaN      0.0
# 237418 2025-01-16 19:26:41    NaN      0.0
#
# [58798 rows x 3 columns]
# Variable: sw_up
#                  timestamp M_slot  sw_up
# 121473 2024-11-14 08:30:40     M1    0.0
# 121474 2024-11-14 08:30:41     M1    0.0
# 121475 2024-11-14 08:30:42     M1    0.0
# 121476 2024-11-14 08:30:43     M1    0.0
# 121477 2024-11-14 08:30:44     M1    0.0
# ...                    ...    ...    ...
# 237414 2025-01-16 19:26:37    NaN    0.0
# 237415 2025-01-16 19:26:38    NaN    0.0
# 237416 2025-01-16 19:26:39    NaN    0.0
# 237417 2025-01-16 19:26:40    NaN    0.0
# 237418 2025-01-16 19:26:41    NaN    0.0
#
# [31435 rows x 3 columns]
# Variable: ws
#                  timestamp M_slot   ws
# 121457 2024-11-14 08:30:24     M1  0.0
# 121503 2024-11-14 08:31:10     M1  0.0
# 121504 2024-11-14 08:31:11     M1  0.0
# 121506 2024-11-14 08:31:13     M1  0.0
# 121613 2024-11-14 08:33:00     M1  0.0
# ...                    ...    ...  ...
# 237185 2025-01-16 19:22:09    NaN  0.0
# 237200 2025-01-16 19:22:25    NaN  0.0
# 237201 2025-01-16 19:22:26    NaN  0.0
# 237202 2025-01-16 19:22:27    NaN  0.0
# 237345 2025-01-16 19:25:28    NaN  0.0
#
# [5826 rows x 3 columns]
# Variable: wdir
#                  timestamp M_slot  wdir
# 124416 2024-11-14 09:33:17     M1     0
# 124418 2024-11-14 09:33:19     M1     0
# 124695 2024-11-14 09:38:17     M1     0
# 124760 2024-11-14 09:39:22     M1     0
# 124797 2024-11-14 09:39:59     M1     0
# ...                    ...    ...   ...
# 235830 2025-01-16 18:54:12     M4     0
# 235835 2025-01-16 18:54:17     M4     0
# 235978 2025-01-16 18:56:40     M4     0
# 236974 2025-01-16 19:17:34    NaN     0
# 236975 2025-01-16 19:17:35    NaN     0
#
# [771 rows x 3 columns]

# %%
display(raw.head())
# Out:
#              project_id  track_id  section_id  segment_id  point_id  \
# 0  picopatt_montpellier  antigone           1           1         1
# 1                   NaN  antigone           1           1         2
# 2                   NaN  antigone           1           1         3
# 3                   NaN  antigone           1           1         4
# 4                   NaN  antigone           1           1         5
#
#    section_duration  section_speed section_warning  gnss_accuracy  \
# 0              27.0       0.640202             NaN           14.0
# 1               NaN            NaN             NaN           14.0
# 2               NaN            NaN             NaN           14.0
# 3               NaN            NaN             NaN           14.0
# 4               NaN            NaN             NaN           14.0
#
#   section_weather           timestamp  lon_ontrack  lat_ontrack   lon_rtk  \
# 0      partialsun 2024-10-29 08:36:30     3.886345    43.608305  3.886365
# 1             NaN 2024-10-29 08:36:31     3.886353    43.608305  3.886365
# 2             NaN 2024-10-29 08:36:32     3.886361    43.608304  3.886366
# 3             NaN 2024-10-29 08:36:33     3.886369    43.608304  3.886371
# 4             NaN 2024-10-29 08:36:34     3.886377    43.608303  3.886376
#
#      lat_rtk  sun_azimuth  sun_height  tair_thermohygro   tair_tc1   tair_tc2  \
# 0  43.608286   109.768202   -0.940810         16.524376  16.343750  16.500000
# 1  43.608286   109.771061   -0.937973         16.524376  16.382812  16.515625
# 2  43.608286   109.773921   -0.935136         16.524376  16.382812  16.523438
# 3  43.608286   109.776781   -0.932300         16.524376  16.359375  16.523438
# 4  43.608286   109.779641   -0.929463         16.503014  16.390625  16.523438
#
#    tair_anemo  rh_thermohygro        ws  wdir      sw_up   sw_front  \
# 0          19       79.706111  0.823110   322  37.882509  37.471904
# 1          19       79.706111  0.668777   314  38.008898  37.466206
# 2          19       79.706111  0.771666   314  37.690569  37.408792
# 3          19       79.706111  0.874555   314  37.899647  37.097180
# 4          19       79.702296  1.028888   312  37.475921  36.667234
#
#      sw_back   sw_right       lw_up     lw_down    lw_front     lw_back  \
# 0  16.708194  39.297944  403.668292  429.132549  422.871330  429.141160
# 1  16.665500  39.278022  403.660049  429.149148  422.843781  429.133003
# 2  16.144093  38.887293  403.677137  429.126754  422.836609  429.103364
# 3  16.734991  39.295227  403.542421  429.272038  422.951980  428.941500
# 4  15.956968  38.248453  403.465898  429.357485  422.908817  428.775405
#
#       lw_left    lw_right       tmrt        pet  \
# 0  431.988721  418.206008  24.091184  15.838465
# 1  431.921867  418.296108  24.086567  16.314185
# 2  431.924360  418.210779  24.053481  15.973879
# 3  431.884754  418.225884  24.074563  15.691999
# 4  431.838899  418.157771  23.994647  15.267798
#
#                                      __source_file       lon        lat  \
# 0  picopatt_montpellier_antigone_20241029_0835.csv  3.886365  43.608286
# 1  picopatt_montpellier_antigone_20241029_0835.csv  3.886365  43.608286
# 2  picopatt_montpellier_antigone_20241029_0835.csv  3.886366  43.608286
# 3  picopatt_montpellier_antigone_20241029_0835.csv  3.886371  43.608286
# 4  picopatt_montpellier_antigone_20241029_0835.csv  3.886376  43.608286
#
#   M_slot        date passage_slot
# 0     M1  2024-10-29           M1
# 1     M1  2024-10-29           M1
# 2     M1  2024-10-29           M1
# 3     M1  2024-10-29           M1
# 4     M1  2024-10-29           M1

# %%
# Drop the 'sw_down' and 'sw_left' columns from the raw DataFrame
columns_to_drop = ['sw_down', 'sw_left']
raw = raw.drop(columns=columns_to_drop)

print(f"Columns {columns_to_drop} dropped from the raw DataFrame.")
print("New shape of raw DataFrame:", raw.shape)
# Out:
# Columns ['sw_down', 'sw_left'] dropped from the raw DataFrame.
# New shape of raw DataFrame: (341281, 42)

# %% [markdown]
# # Task
# Apply the following correction strategy to all numerical columns in each data file located in the "DATA_DIR" directory: if a sequence of consecutive zeros is longer than 10, replace the zeros with NaN; otherwise, replace each zero with the mean of its non-zero neighbors.

# %% [markdown]
# ## Identify relevant files
#
# ### Subtask:
# Get the list of original data files (CSV or Excel) from the `DATA_DIR`.

# %% [markdown]
# **Reasoning**:
# Get the list of original data files (CSV or Excel) from the DATA_DIR.

# %%
data_files = sorted([p for p in DATA_DIR.rglob("*") if p.suffix.lower() in (".csv", ".xlsx", ".xls")])
print(f"Found {len(data_files)} data files:")
for f in data_files:
    print(f)
# Out:
# Found 73 data files:
# /content/drive/MyDrive/dataproc/picopatt_montpellier_antigone_20241029_0835.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_antigone_20241029_1127.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_antigone_20241029_1423.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_antigone_20241029_1722.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_antigone_20241107_0831.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_antigone_20241107_1122.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_antigone_20241107_1429.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_antigone_20241107_1727.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_antigone_20241119_0847.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_antigone_20241119_1127.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_antigone_20241119_1421.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_antigone_20241119_1724.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_antigone_20241128_0836.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_antigone_20241128_1124.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_antigone_20241128_1429.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_antigone_20241128_1728.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_antigone_20241206_1443.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_antigone_20241210_0841.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_antigone_20241210_1130.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_antigone_20241210_1427.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_antigone_20241210_1729.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_antigone_20241219_0834.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_antigone_20241219_1124.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_antigone_20241219_1428.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_antigone_20241219_1724.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_antigone_20250109_0831.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_antigone_20250109_1123.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_antigone_20250109_1429.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_antigone_20250109_1726.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_boulevards_20241114_0828.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_boulevards_20241114_1121.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_boulevards_20241114_1429.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_boulevards_20241114_1728.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_boulevards_20241126_0822.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_boulevards_20241126_1127.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_boulevards_20241126_1423.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_boulevards_20241126_1726.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_boulevards_20241205_0822.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_boulevards_20241205_1124.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_boulevards_20241205_1430.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_boulevards_20241205_1729.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_boulevards_20241206_1132.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_boulevards_20241217_0827.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_boulevards_20241217_1128.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_boulevards_20241217_1726.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_boulevards_20250107_1126.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_boulevards_20250107_1424.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_boulevards_20250107_1727.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_boulevards_20250116_0834.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_boulevards_20250116_1126.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_boulevards_20250116_1430.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_boulevards_20250116_1725.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_ecusson_20241031_0827.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_ecusson_20241031_1127.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_ecusson_20241031_1425.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_ecusson_20241112_0830.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_ecusson_20241112_1124.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_ecusson_20241112_1430.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_ecusson_20241112_1723.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_ecusson_20241121_0832.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_ecusson_20241121_1729.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_ecusson_20241203_0829.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_ecusson_20241203_1128.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_ecusson_20241203_1423.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_ecusson_20241203_1743.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_ecusson_20241206_1005.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_ecusson_20241212_0829.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_ecusson_20241212_1125.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_ecusson_20241212_1425.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_ecusson_20250114_0832.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_ecusson_20250114_1130.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_ecusson_20250114_1427.csv
# /content/drive/MyDrive/dataproc/picopatt_montpellier_ecusson_20250114_1726.csv

# %% [markdown]
# ## Process each file
#
# ### Subtask:
# Iterate through the list of files.

# %% [markdown]
# **Reasoning**:
# Iterate through the list of files to process each one individually.

# %%
for file_path in data_files:
    print(f"Processing file: {file_path.name}")
    # The subsequent steps will be implemented within this loop
# Out:
# Processing file: picopatt_montpellier_antigone_20241029_0835.csv
# Processing file: picopatt_montpellier_antigone_20241029_1127.csv
# Processing file: picopatt_montpellier_antigone_20241029_1423.csv
# Processing file: picopatt_montpellier_antigone_20241029_1722.csv
# Processing file: picopatt_montpellier_antigone_20241107_0831.csv
# Processing file: picopatt_montpellier_antigone_20241107_1122.csv
# Processing file: picopatt_montpellier_antigone_20241107_1429.csv
# Processing file: picopatt_montpellier_antigone_20241107_1727.csv
# Processing file: picopatt_montpellier_antigone_20241119_0847.csv
# Processing file: picopatt_montpellier_antigone_20241119_1127.csv
# Processing file: picopatt_montpellier_antigone_20241119_1421.csv
# Processing file: picopatt_montpellier_antigone_20241119_1724.csv
# Processing file: picopatt_montpellier_antigone_20241128_0836.csv
# Processing file: picopatt_montpellier_antigone_20241128_1124.csv
# Processing file: picopatt_montpellier_antigone_20241128_1429.csv
# Processing file: picopatt_montpellier_antigone_20241128_1728.csv
# Processing file: picopatt_montpellier_antigone_20241206_1443.csv
# Processing file: picopatt_montpellier_antigone_20241210_0841.csv
# Processing file: picopatt_montpellier_antigone_20241210_1130.csv
# Processing file: picopatt_montpellier_antigone_20241210_1427.csv
# Processing file: picopatt_montpellier_antigone_20241210_1729.csv
# Processing file: picopatt_montpellier_antigone_20241219_0834.csv
# Processing file: picopatt_montpellier_antigone_20241219_1124.csv
# Processing file: picopatt_montpellier_antigone_20241219_1428.csv
# Processing file: picopatt_montpellier_antigone_20241219_1724.csv
# Processing file: picopatt_montpellier_antigone_20250109_0831.csv
# Processing file: picopatt_montpellier_antigone_20250109_1123.csv
# Processing file: picopatt_montpellier_antigone_20250109_1429.csv
# Processing file: picopatt_montpellier_antigone_20250109_1726.csv
# Processing file: picopatt_montpellier_boulevards_20241114_0828.csv
# Processing file: picopatt_montpellier_boulevards_20241114_1121.csv
# Processing file: picopatt_montpellier_boulevards_20241114_1429.csv
# Processing file: picopatt_montpellier_boulevards_20241114_1728.csv
# Processing file: picopatt_montpellier_boulevards_20241126_0822.csv
# Processing file: picopatt_montpellier_boulevards_20241126_1127.csv
# Processing file: picopatt_montpellier_boulevards_20241126_1423.csv
# Processing file: picopatt_montpellier_boulevards_20241126_1726.csv
# Processing file: picopatt_montpellier_boulevards_20241205_0822.csv
# Processing file: picopatt_montpellier_boulevards_20241205_1124.csv
# Processing file: picopatt_montpellier_boulevards_20241205_1430.csv
# Processing file: picopatt_montpellier_boulevards_20241205_1729.csv
# Processing file: picopatt_montpellier_boulevards_20241206_1132.csv
# Processing file: picopatt_montpellier_boulevards_20241217_0827.csv
# Processing file: picopatt_montpellier_boulevards_20241217_1128.csv
# Processing file: picopatt_montpellier_boulevards_20241217_1726.csv
# Processing file: picopatt_montpellier_boulevards_20250107_1126.csv
# Processing file: picopatt_montpellier_boulevards_20250107_1424.csv
# Processing file: picopatt_montpellier_boulevards_20250107_1727.csv
# Processing file: picopatt_montpellier_boulevards_20250116_0834.csv
# Processing file: picopatt_montpellier_boulevards_20250116_1126.csv
# Processing file: picopatt_montpellier_boulevards_20250116_1430.csv
# Processing file: picopatt_montpellier_boulevards_20250116_1725.csv
# Processing file: picopatt_montpellier_ecusson_20241031_0827.csv
# Processing file: picopatt_montpellier_ecusson_20241031_1127.csv
# Processing file: picopatt_montpellier_ecusson_20241031_1425.csv
# Processing file: picopatt_montpellier_ecusson_20241112_0830.csv
# Processing file: picopatt_montpellier_ecusson_20241112_1124.csv
# Processing file: picopatt_montpellier_ecusson_20241112_1430.csv
# Processing file: picopatt_montpellier_ecusson_20241112_1723.csv
# Processing file: picopatt_montpellier_ecusson_20241121_0832.csv
# Processing file: picopatt_montpellier_ecusson_20241121_1729.csv
# Processing file: picopatt_montpellier_ecusson_20241203_0829.csv
# Processing file: picopatt_montpellier_ecusson_20241203_1128.csv
# Processing file: picopatt_montpellier_ecusson_20241203_1423.csv
# Processing file: picopatt_montpellier_ecusson_20241203_1743.csv
# Processing file: picopatt_montpellier_ecusson_20241206_1005.csv
# Processing file: picopatt_montpellier_ecusson_20241212_0829.csv
# Processing file: picopatt_montpellier_ecusson_20241212_1125.csv
# Processing file: picopatt_montpellier_ecusson_20241212_1425.csv
# Processing file: picopatt_montpellier_ecusson_20250114_0832.csv
# Processing file: picopatt_montpellier_ecusson_20250114_1130.csv
# Processing file: picopatt_montpellier_ecusson_20250114_1427.csv
# Processing file: picopatt_montpellier_ecusson_20250114_1726.csv

# %% [markdown]
# ## Load data from file
#
# ### Subtask:
# Read the data from the current file into a pandas DataFrame.

# %% [markdown]
# **Reasoning**:
# Read the current data file into a pandas DataFrame using the defined read_any function and print a confirmation.

# %%
df = read_any(file_path)
print(f"Loaded file: {file_path.name} with shape {df.shape}")
# Out:
# Loaded file: picopatt_montpellier_ecusson_20250114_1726.csv with shape (5139, 39)

# %% [markdown]
# ## Identify consecutive zeros
#
# ### Subtask:
# For each numerical column in the current DataFrame, identify sequences of consecutive zero values.

# %% [markdown]
# **Reasoning**:
# Identify the numerical columns in the DataFrame and then iterate through each numerical column to find and store the indices of consecutive zero sequences.

# %%
numerical_cols = df.select_dtypes(include=np.number).columns.tolist()

zero_sequences = {}

for col in numerical_cols:
    zero_indices = df.index[df[col] == 0].tolist()
    if not zero_indices:
        continue

    sequences = []
    current_sequence = []

    for i in range(len(zero_indices)):
        if not current_sequence:
            current_sequence.append(zero_indices[i])
        elif zero_indices[i] == current_sequence[-1] + 1:
            current_sequence.append(zero_indices[i])
        else:
            sequences.append(current_sequence)
            current_sequence = [zero_indices[i]]

    if current_sequence:
        sequences.append(current_sequence)

    if sequences:
        zero_sequences[col] = sequences

for col, sequences in zero_sequences.items():
    print(f"Column: {col}")
    for seq in sequences:
        print(f"  Consecutive zero sequence indices: {seq}")
